# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahamruf/Mosquito/blob/main/ensemble_other_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Average
model_1 = load_model('/content/drive/MyDrive/model-05-0.8400.hdf5')
model_1 = Model(inputs=model_1.inputs,
                outputs=model_1.outputs,
                name='name_of_model_1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model_2 = load_model('/content/drive/MyDrive/model2-05-0.5667.hdf5')
model_2 = Model(inputs=model_2.inputs,
                outputs=model_2.outputs,
                name='name_of_model_2')

# %%
model_3 = load_model('/content/drive/MyDrive/resnetmosquito-04-0.8000.hdf5')
model_3 = Model(inputs=model_3.inputs,
                outputs=model_3.outputs,
                name='name_of_model_3')

# %%
models = [model_1, model_2 ,model_3]
model_input = Input(shape=(299, 299, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = Average()(model_outputs)
ensemble_model = Model(inputs=model_input, outputs=ensemble_output, name='ensemble')

# %%
import tensorflow as tf

# %%
base_learning_rate = 0.001
ensemble_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tensorflow import keras
import glob as gb
import pandas as pd
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU

# %%
IMG_SIZE = (299, 299)  # resolution
directory = "/content/drive/MyDrive/Mosquito_Raw"
BATCH_SIZE = 128
import os
from sklearn.model_selection import train_test_split


# Original directory
original_directory = "/content/drive/MyDrive/Mosquito_Raw"

# Create train/validation/test split
train_dir, test_dir = train_test_split(os.listdir(original_directory), test_size=0.2, random_state=42)
train_dir, val_dir = train_test_split(train_dir, test_size=0.1, random_state=42)

# Create training dataset
train_dataset = image_dataset_from_directory(
    original_directory,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.2,
    subset='training',
    color_mode='rgb',
    seed=42
)

# Create validation dataset
validation_dataset = image_dataset_from_directory(
    original_directory,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.2,
    subset='validation',
    color_mode='rgb',
    seed=42
)

# Create testing dataset
test_dataset = image_dataset_from_directory(
    original_directory,
    labels='inferred',
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    validation_split=0.2,  # Adjust the split if needed
    subset='validation',  # Note: Use 'validation' here as it's common practice
    color_mode='rgb',
    seed=42
)
# Out:
# Found 3578 files belonging to 6 classes.
# Using 2863 files for training.
# Found 3578 files belonging to 6 classes.
# Using 715 files for validation.
# Found 3578 files belonging to 6 classes.
# Using 715 files for validation.

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(directory):
    files = gb.glob(pathname=str(directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
# plt.figure(figsize=(13,7))
# sns.barplot(x=[ "Aedes aegypti landing", "EUS", "Aedes aegypti smashed","Aedes albopictus smashed","Culex quinquefasciatus landing","Culex quinquefasciatus smashed"], y=Data_imbalance, palette="rocket")
# plt.show()

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
# total = 0
# for i in range(0,len(Data_imbalance)) :
#     total +=Data_imbalance[i]

# weight_for_0 = (1 / Data_imbalance[0]) * (total / 3.0)
# weight_for_1 = (1 / Data_imbalance[1]) * (total / 3.0)
# weight_for_2 = (1 / Data_imbalance[2]) * (total / 3.0)
# # weight_for_3 = (1 / Data_imbalance[3]) * (total / 6.0)
# # weight_for_4 = (1 / Data_imbalance[3]) * (total / 6.0)
# # weight_for_5 = (1 / Data_imbalance[3]) * (total / 6.0)

# class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2}

# print('Weight for class 0: {:.2f}'.format(weight_for_0))
# print('Weight for class 1: {:.2f}'.format(weight_for_1))
# print('Weight for class 2: {:.2f}'.format(weight_for_2))
# # print('Weight for class 3: {:.2f}'.format(weight_for_3))
# # print('Weight for class 4: {:.2f}'.format(weight_for_4))
# # print('Weight for class 5: {:.2f}'.format(weight_for_5))

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
model_filepath="/content/drive/MyDrive/Colab Notebooks/emsemble-2-best-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
     verbose = 1

)

# %%
history = ensemble_model.fit(train_dataset , verbose=2 , epochs=100 ,
                               validation_data=validation_dataset , use_multiprocessing= True )
# Out:
# Epoch 1/100
# 23/23 - 150s - loss: 1.8338 - accuracy: 0.2606 - val_loss: 1.4173 - val_accuracy: 0.3650 - 150s/epoch - 7s/step
# Epoch 2/100
# 23/23 - 73s - loss: 1.3523 - accuracy: 0.4408 - val_loss: 1.1737 - val_accuracy: 0.5427 - 73s/epoch - 3s/step
# Epoch 3/100
# 23/23 - 73s - loss: 1.1558 - accuracy: 0.5648 - val_loss: 1.0556 - val_accuracy: 0.5832 - 73s/epoch - 3s/step
# Epoch 4/100
# 23/23 - 73s - loss: 1.0544 - accuracy: 0.6130 - val_loss: 0.9779 - val_accuracy: 0.6643 - 73s/epoch - 3s/step
# Epoch 5/100
# 23/23 - 74s - loss: 1.0001 - accuracy: 0.6490 - val_loss: 0.9232 - val_accuracy: 0.7035 - 74s/epoch - 3s/step
# Epoch 6/100
# 23/23 - 74s - loss: 0.9408 - accuracy: 0.6808 - val_loss: 0.8879 - val_accuracy: 0.7245 - 74s/epoch - 3s/step
# Epoch 7/100
# 23/23 - 73s - loss: 0.9066 - accuracy: 0.6916 - val_loss: 0.8458 - val_accuracy: 0.7469 - 73s/epoch - 3s/step
# Epoch 8/100
# 23/23 - 73s - loss: 0.8515 - accuracy: 0.7321 - val_loss: 0.7973 - val_accuracy: 0.7678 - 73s/epoch - 3s/step
# Epoch 9/100
# 23/23 - 73s - loss: 0.8082 - accuracy: 0.7485 - val_loss: 0.7704 - val_accuracy: 0.7678 - 73s/epoch - 3s/step
# Epoch 10/100
# 23/23 - 73s - loss: 0.7799 - accuracy: 0.7600 - val_loss: 0.7427 - val_accuracy: 0.7804 - 73s/epoch - 3s/step
# Epoch 11/100
# 23/23 - 73s - loss: 0.7609 - accuracy: 0.7621 - val_loss: 0.7224 - val_accuracy: 0.7986 - 73s/epoch - 3s/step
# Epoch 12/100
# 23/23 - 72s - loss: 0.7413 - accuracy: 0.7813 - val_loss: 0.7120 - val_accuracy: 0.7930 - 72s/epoch - 3s/step
# Epoch 13/100
# 23/23 - 72s - loss: 0.7332 - accuracy: 0.7820 - val_loss: 0.6999 - val_accuracy: 0.7944 - 72s/epoch - 3s/step
# Epoch 14/100
# 23/23 - 73s - loss: 0.7212 - accuracy: 0.7848 - val_loss: 0.6854 - val_accuracy: 0.8224 - 73s/epoch - 3s/step
# Epoch 15/100
# 23/23 - 73s - loss: 0.7057 - accuracy: 0.7880 - val_loss: 0.6764 - val_accuracy: 0.8336 - 73s/epoch - 3s/step
# Epoch 16/100
# 23/23 - 73s - loss: 0.7037 - accuracy: 0.7978 - val_loss: 0.6709 - val_accuracy: 0.8350 - 73s/epoch - 3s/step
# Epoch 17/100
# 23/23 - 73s - loss: 0.6866 - accuracy: 0.8016 - val_loss: 0.6694 - val_accuracy: 0.8238 - 73s/epoch - 3s/step
# Epoch 18/100
# 23/23 - 73s - loss: 0.6814 - accuracy: 0.7981 - val_loss: 0.6586 - val_accuracy: 0.8280 - 73s/epoch - 3s/step
# Epoch 19/100
# 23/23 - 74s - loss: 0.6801 - accuracy: 0.8030 - val_loss: 0.6528 - val_accuracy: 0.8350 - 74s/epoch - 3s/step
# Epoch 20/100
# 23/23 - 74s - loss: 0.6735 - accuracy: 0.8082 - val_loss: 0.6492 - val_accuracy: 0.8364 - 74s/epoch - 3s/step
# Epoch 21/100
# 23/23 - 73s - loss: 0.6731 - accuracy: 0.8079 - val_loss: 0.6489 - val_accuracy: 0.8420 - 73s/epoch - 3s/step
# Epoch 22/100
# 23/23 - 73s - loss: 0.6687 - accuracy: 0.8100 - val_loss: 0.6406 - val_accuracy: 0.8462 - 73s/epoch - 3s/step
# Epoch 23/100
# 23/23 - 74s - loss: 0.6661 - accuracy: 0.8051 - val_loss: 0.6377 - val_accuracy: 0.8448 - 74s/epoch - 3s/step
# Epoch 24/100
# 23/23 - 73s - loss: 0.6575 - accuracy: 0.8121 - val_loss: 0.6374 - val_accuracy: 0.8350 - 73s/epoch - 3s/step
# Epoch 25/100
# 23/23 - 73s - loss: 0.6495 - accuracy: 0.8222 - val_loss: 0.6328 - val_accuracy: 0.8490 - 73s/epoch - 3s/step
# Epoch 26/100
# 23/23 - 73s - loss: 0.6539 - accuracy: 0.8114 - val_loss: 0.6275 - val_accuracy: 0.8434 - 73s/epoch - 3s/step
# Epoch 27/100
# 23/23 - 72s - loss: 0.6514 - accuracy: 0.8142 - val_loss: 0.6257 - val_accuracy: 0.8420 - 72s/epoch - 3s/step
# Epoch 28/100
# 23/23 - 72s - loss: 0.6491 - accuracy: 0.8180 - val_loss: 0.6231 - val_accuracy: 0.8434 - 72s/epoch - 3s/step
# Epoch 29/100
# 23/23 - 72s - loss: 0.6439 - accuracy: 0.8124 - val_loss: 0.6224 - val_accuracy: 0.8392 - 72s/epoch - 3s/step
# Epoch 30/100
# 23/23 - 72s - loss: 0.6423 - accuracy: 0.8156 - val_loss: 0.6186 - val_accuracy: 0.8531 - 72s/epoch - 3s/step
# Epoch 31/100
# 23/23 - 73s - loss: 0.6396 - accuracy: 0.8268 - val_loss: 0.6182 - val_accuracy: 0.8462 - 73s/epoch - 3s/step
# Epoch 32/100
# 23/23 - 73s - loss: 0.6363 - accuracy: 0.8138 - val_loss: 0.6178 - val_accuracy: 0.8406 - 73s/epoch - 3s/step
# Epoch 33/100
# 23/23 - 73s - loss: 0.6337 - accuracy: 0.8278 - val_loss: 0.6055 - val_accuracy: 0.8657 - 73s/epoch - 3s/step
# Epoch 34/100
# 23/23 - 73s - loss: 0.6193 - accuracy: 0.8488 - val_loss: 0.5678 - val_accuracy: 0.9245 - 73s/epoch - 3s/step
# Epoch 35/100
# 23/23 - 73s - loss: 0.5749 - accuracy: 0.9046 - val_loss: 0.5432 - val_accuracy: 0.9399 - 73s/epoch - 3s/step
# Epoch 36/100
# 23/23 - 73s - loss: 0.5577 - accuracy: 0.9165 - val_loss: 0.5382 - val_accuracy: 0.9385 - 73s/epoch - 3s/step
# Epoch 37/100
# 23/23 - 73s - loss: 0.5446 - accuracy: 0.9333 - val_loss: 0.5266 - val_accuracy: 0.9077 - 73s/epoch - 3s/step
# Epoch 38/100
# 23/23 - 73s - loss: 0.5165 - accuracy: 0.9326 - val_loss: 0.5010 - val_accuracy: 0.9287 - 73s/epoch - 3s/step
# Epoch 39/100
# 23/23 - 73s - loss: 0.4904 - accuracy: 0.9392 - val_loss: 0.4835 - val_accuracy: 0.9692 - 73s/epoch - 3s/step
# Epoch 40/100
# 23/23 - 73s - loss: 0.4898 - accuracy: 0.9424 - val_loss: 0.4831 - val_accuracy: 0.9510 - 73s/epoch - 3s/step
# Epoch 41/100
# 23/23 - 73s - loss: 0.4782 - accuracy: 0.9427 - val_loss: 0.4736 - val_accuracy: 0.9692 - 73s/epoch - 3s/step
# Epoch 42/100
# 23/23 - 73s - loss: 0.4760 - accuracy: 0.9480 - val_loss: 0.4668 - val_accuracy: 0.9664 - 73s/epoch - 3s/step
# Epoch 43/100
# 23/23 - 74s - loss: 0.4662 - accuracy: 0.9525 - val_loss: 0.4631 - val_accuracy: 0.9664 - 74s/epoch - 3s/step
# Epoch 44/100
# 23/23 - 73s - loss: 0.4638 - accuracy: 0.9518 - val_loss: 0.4647 - val_accuracy: 0.9552 - 73s/epoch - 3s/step
# Epoch 45/100
# 23/23 - 73s - loss: 0.4629 - accuracy: 0.9514 - val_loss: 0.4588 - val_accuracy: 0.9720 - 73s/epoch - 3s/step
# Epoch 46/100
# 23/23 - 73s - loss: 0.4560 - accuracy: 0.9588 - val_loss: 0.4572 - val_accuracy: 0.9706 - 73s/epoch - 3s/step
# Epoch 47/100
# 23/23 - 73s - loss: 0.4531 - accuracy: 0.9595 - val_loss: 0.4527 - val_accuracy: 0.9678 - 73s/epoch - 3s/step
# Epoch 48/100
# 23/23 - 73s - loss: 0.4582 - accuracy: 0.9563 - val_loss: 0.4518 - val_accuracy: 0.9734 - 73s/epoch - 3s/step
# Epoch 49/100
# 23/23 - 73s - loss: 0.4544 - accuracy: 0.9567 - val_loss: 0.4521 - val_accuracy: 0.9664 - 73s/epoch - 3s/step
# Epoch 50/100
# 23/23 - 73s - loss: 0.4535 - accuracy: 0.9553 - val_loss: 0.4533 - val_accuracy: 0.9692 - 73s/epoch - 3s/step
# Epoch 51/100
# 23/23 - 73s - loss: 0.4510 - accuracy: 0.9595 - val_loss: 0.4462 - val_accuracy: 0.9734 - 73s/epoch - 3s/step
# Epoch 52/100
# 23/23 - 73s - loss: 0.4447 - accuracy: 0.9630 - val_loss: 0.4493 - val_accuracy: 0.9650 - 73s/epoch - 3s/step
# Epoch 53/100
# 23/23 - 73s - loss: 0.4475 - accuracy: 0.9584 - val_loss: 0.4488 - val_accuracy: 0.9650 - 73s/epoch - 3s/step
# Epoch 54/100
# 23/23 - 72s - loss: 0.4432 - accuracy: 0.9588 - val_loss: 0.4506 - val_accuracy: 0.9720 - 72s/epoch - 3s/step
# Epoch 55/100
# 23/23 - 72s - loss: 0.4426 - accuracy: 0.9735 - val_loss: 0.4443 - val_accuracy: 0.9734 - 72s/epoch - 3s/step
# Epoch 56/100
# 23/23 - 72s - loss: 0.4424 - accuracy: 0.9623 - val_loss: 0.4411 - val_accuracy: 0.9776 - 72s/epoch - 3s/step
# Epoch 57/100
# 23/23 - 73s - loss: 0.4398 - accuracy: 0.9651 - val_loss: 0.4410 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 58/100
# 23/23 - 73s - loss: 0.4336 - accuracy: 0.9707 - val_loss: 0.4416 - val_accuracy: 0.9790 - 73s/epoch - 3s/step
# Epoch 59/100
# 23/23 - 73s - loss: 0.4383 - accuracy: 0.9661 - val_loss: 0.4391 - val_accuracy: 0.9734 - 73s/epoch - 3s/step
# Epoch 60/100
# 23/23 - 73s - loss: 0.4409 - accuracy: 0.9675 - val_loss: 0.4380 - val_accuracy: 0.9734 - 73s/epoch - 3s/step
# Epoch 61/100
# 23/23 - 73s - loss: 0.4325 - accuracy: 0.9675 - val_loss: 0.4394 - val_accuracy: 0.9650 - 73s/epoch - 3s/step
# Epoch 62/100
# 23/23 - 73s - loss: 0.4378 - accuracy: 0.9668 - val_loss: 0.4374 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 63/100
# 23/23 - 73s - loss: 0.4295 - accuracy: 0.9700 - val_loss: 0.4351 - val_accuracy: 0.9790 - 73s/epoch - 3s/step
# Epoch 64/100
# 23/23 - 74s - loss: 0.4309 - accuracy: 0.9689 - val_loss: 0.4360 - val_accuracy: 0.9776 - 74s/epoch - 3s/step
# Epoch 65/100
# 23/23 - 74s - loss: 0.4320 - accuracy: 0.9700 - val_loss: 0.4360 - val_accuracy: 0.9776 - 74s/epoch - 3s/step
# Epoch 66/100
# 23/23 - 73s - loss: 0.4251 - accuracy: 0.9728 - val_loss: 0.4342 - val_accuracy: 0.9790 - 73s/epoch - 3s/step
# Epoch 67/100
# 23/23 - 73s - loss: 0.4283 - accuracy: 0.9714 - val_loss: 0.4368 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 68/100
# 23/23 - 73s - loss: 0.4296 - accuracy: 0.9700 - val_loss: 0.4344 - val_accuracy: 0.9776 - 73s/epoch - 3s/step
# Epoch 69/100
# 23/23 - 73s - loss: 0.4252 - accuracy: 0.9714 - val_loss: 0.4308 - val_accuracy: 0.9776 - 73s/epoch - 3s/step
# Epoch 70/100
# 23/23 - 72s - loss: 0.4268 - accuracy: 0.9682 - val_loss: 0.4313 - val_accuracy: 0.9762 - 72s/epoch - 3s/step
# Epoch 71/100
# 23/23 - 72s - loss: 0.4275 - accuracy: 0.9714 - val_loss: 0.4289 - val_accuracy: 0.9804 - 72s/epoch - 3s/step
# Epoch 72/100
# 23/23 - 72s - loss: 0.4258 - accuracy: 0.9717 - val_loss: 0.4298 - val_accuracy: 0.9790 - 72s/epoch - 3s/step
# Epoch 73/100
# 23/23 - 73s - loss: 0.4253 - accuracy: 0.9731 - val_loss: 0.4302 - val_accuracy: 0.9762 - 73s/epoch - 3s/step
# Epoch 74/100
# 23/23 - 73s - loss: 0.4208 - accuracy: 0.9689 - val_loss: 0.4306 - val_accuracy: 0.9790 - 73s/epoch - 3s/step
# Epoch 75/100
# 23/23 - 73s - loss: 0.4200 - accuracy: 0.9756 - val_loss: 0.4318 - val_accuracy: 0.9748 - 73s/epoch - 3s/step
# Epoch 76/100
# 23/23 - 73s - loss: 0.4254 - accuracy: 0.9738 - val_loss: 0.4264 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 77/100
# 23/23 - 73s - loss: 0.4196 - accuracy: 0.9707 - val_loss: 0.4235 - val_accuracy: 0.9832 - 73s/epoch - 3s/step
# Epoch 78/100
# 23/23 - 73s - loss: 0.4166 - accuracy: 0.9797 - val_loss: 0.4251 - val_accuracy: 0.9818 - 73s/epoch - 3s/step
# Epoch 79/100
# 23/23 - 73s - loss: 0.4202 - accuracy: 0.9762 - val_loss: 0.4239 - val_accuracy: 0.9818 - 73s/epoch - 3s/step
# Epoch 80/100
# 23/23 - 73s - loss: 0.4195 - accuracy: 0.9742 - val_loss: 0.4218 - val_accuracy: 0.9818 - 73s/epoch - 3s/step
# Epoch 81/100
# 23/23 - 73s - loss: 0.4127 - accuracy: 0.9776 - val_loss: 0.4231 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 82/100
# 23/23 - 73s - loss: 0.4161 - accuracy: 0.9769 - val_loss: 0.4238 - val_accuracy: 0.9762 - 73s/epoch - 3s/step
# Epoch 83/100
# 23/23 - 73s - loss: 0.4167 - accuracy: 0.9738 - val_loss: 0.4246 - val_accuracy: 0.9832 - 73s/epoch - 3s/step
# Epoch 84/100
# 23/23 - 73s - loss: 0.4178 - accuracy: 0.9759 - val_loss: 0.4205 - val_accuracy: 0.9832 - 73s/epoch - 3s/step
# Epoch 85/100
# 23/23 - 73s - loss: 0.4139 - accuracy: 0.9756 - val_loss: 0.4204 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 86/100
# 23/23 - 73s - loss: 0.4197 - accuracy: 0.9735 - val_loss: 0.4215 - val_accuracy: 0.9832 - 73s/epoch - 3s/step
# Epoch 87/100
# 23/23 - 73s - loss: 0.4149 - accuracy: 0.9776 - val_loss: 0.4215 - val_accuracy: 0.9846 - 73s/epoch - 3s/step
# Epoch 88/100
# 23/23 - 73s - loss: 0.4141 - accuracy: 0.9756 - val_loss: 0.4210 - val_accuracy: 0.9832 - 73s/epoch - 3s/step
# Epoch 89/100
# 23/23 - 73s - loss: 0.4198 - accuracy: 0.9766 - val_loss: 0.4187 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 90/100
# 23/23 - 73s - loss: 0.4134 - accuracy: 0.9808 - val_loss: 0.4175 - val_accuracy: 0.9818 - 73s/epoch - 3s/step
# Epoch 91/100
# 23/23 - 73s - loss: 0.4150 - accuracy: 0.9756 - val_loss: 0.4183 - val_accuracy: 0.9832 - 73s/epoch - 3s/step
# Epoch 92/100
# 23/23 - 73s - loss: 0.4126 - accuracy: 0.9742 - val_loss: 0.4187 - val_accuracy: 0.9846 - 73s/epoch - 3s/step
# Epoch 93/100
# 23/23 - 73s - loss: 0.4117 - accuracy: 0.9822 - val_loss: 0.4206 - val_accuracy: 0.9846 - 73s/epoch - 3s/step
# Epoch 94/100
# 23/23 - 72s - loss: 0.4055 - accuracy: 0.9797 - val_loss: 0.4212 - val_accuracy: 0.9818 - 72s/epoch - 3s/step
# Epoch 95/100
# 23/23 - 72s - loss: 0.4038 - accuracy: 0.9815 - val_loss: 0.4177 - val_accuracy: 0.9832 - 72s/epoch - 3s/step
# Epoch 96/100
# 23/23 - 73s - loss: 0.4096 - accuracy: 0.9790 - val_loss: 0.4204 - val_accuracy: 0.9804 - 73s/epoch - 3s/step
# Epoch 97/100
# 23/23 - 73s - loss: 0.4090 - accuracy: 0.9794 - val_loss: 0.4173 - val_accuracy: 0.9790 - 73s/epoch - 3s/step
# Epoch 98/100
# 23/23 - 73s - loss: 0.4083 - accuracy: 0.9766 - val_loss: 0.4159 - val_accuracy: 0.9832 - 73s/epoch - 3s/step
# Epoch 99/100
# 23/23 - 73s - loss: 0.4096 - accuracy: 0.9801 - val_loss: 0.4157 - val_accuracy: 0.9846 - 73s/epoch - 3s/step
# Epoch 100/100
# 23/23 - 73s - loss: 0.4103 - accuracy: 0.9769 - val_loss: 0.4140 - val_accuracy: 0.9832 - 73s/epoch - 3s/step

# %%
from tensorflow.keras.models import load_model

# %%
ensemble_model.evaluate(test_dataset , verbose = 1)
# Out:
# 6/6 [==============================] - 15s 2s/step - loss: 0.4140 - accuracy: 0.9832
# [0.413968950510025, 0.9832167625427246]

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Aedes albopictus',
#  'Aedes vexans',
#  'Anopheles sinensis',
#  'Culex pipiens',
#  'Culex tritaeniorhynchus',
#  'Non vectors']

# %%
plt.figure(figsize=(20, 15))
for images, labels in test_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = ensemble_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in test_dataset:
    predictions = ensemble_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves with different colors and line styles
plt.figure(figsize=(10, 8))

colors = plt.cm.rainbow(np.linspace(0, 1, len(class_names)))

for i, color in zip(range(len(class_names)), colors):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr, tpr,
        label=f'{class_names[i]} (AUC = {roc_auc:.2f})',
        color=color,
        linestyle='-',  # You can customize line styles here
        linewidth=2,  # You can customize line width here
        alpha=0.8  # You can customize transparency here
    )

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification')
plt.legend(loc='lower right')
plt.grid(True)  # Add a grid for better readability
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 13s 384ms/step
# 4/4 [==============================] - 2s 553ms/step
# 4/4 [==============================] - 2s 557ms/step
# 4/4 [==============================] - 2s 560ms/step
# 4/4 [==============================] - 2s 559ms/step
# 3/3 [==============================] - 8s 3s/step
# ROC AUC for Aedes albopictus: 0.9900
# ROC AUC for Aedes vexans: 0.9757
# ROC AUC for Anopheles sinensis: 0.9941
# ROC AUC for Culex pipiens: 0.9943
# ROC AUC for Culex tritaeniorhynchus: 0.9870
# ROC AUC for Non vectors: 1.0000
#                          precision    recall  f1-score   support
#
#        Aedes albopictus       1.00      0.98      0.99       100
#            Aedes vexans       0.98      0.95      0.97       133
#      Anopheles sinensis       0.98      0.99      0.99       119
#           Culex pipiens       0.94      1.00      0.97       104
# Culex tritaeniorhynchus       0.99      0.98      0.98       123
#             Non vectors       1.00      1.00      1.00       136
#
#                accuracy                           0.98       715
#               macro avg       0.98      0.98      0.98       715
#            weighted avg       0.98      0.98      0.98       715

# %%
from sklearn.metrics import cohen_kappa_score

kappa = cohen_kappa_score(true_labels, predicted_labels)
print(f'Cohen\'s Kappa: {kappa:.4f}')
# Out:
# Cohen's Kappa: 0.9798

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Set a custom color palette (cividis is a good choice for accessibility)
custom_palette = sns.color_palette("cividis", as_cmap=True)

# Plot the confusion matrix as a heatmap with custom styling
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=custom_palette, xticklabels=class_names, yticklabels=class_names, cbar=False)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.title('Confusion Matrix (Ensemble model 2)', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
from sklearn.metrics import matthews_corrcoef
import numpy as np

# Assuming true_labels and predicted_labels are your multiclass labels
mcc_values = [matthews_corrcoef(true_labels == i, predicted_labels == i) for i in np.unique(true_labels)]

average_mcc = np.mean(mcc_values)
print(f'Average Matthews Correlation Coefficient for Multiclass: {average_mcc:.4f}')
# Out:
# Average Matthews Correlation Coefficient for Multiclass: 0.9798

# %%
from sklearn.metrics import precision_recall_curve

plt.figure(figsize=(10, 8))

for i, color in zip(range(len(class_names)), colors):
    precision, recall, _ = precision_recall_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    plt.plot(
        recall, precision,
        label=f'{class_names[i]}',
        color=color,
        linestyle='-',
        linewidth=2,
        alpha=0.8
    )

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves for Multiclass Mosquito Species  Classification (Ensemble Model 2)')
plt.legend(loc='lower left')
plt.grid(True)
plt.show()

# %%
from sklearn.calibration import calibration_curve

plt.figure(figsize=(8, 8))

for i in range(len(class_names)):
    prob_true, prob_pred = calibration_curve(true_labels_bin[:, i], predicted_labels_bin[:, i], n_bins=10, strategy='uniform')
    plt.plot(prob_pred, prob_true, marker='o', label=f'{class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('Mean Predicted Probability')
plt.ylabel('Fraction of Positives')
plt.title('Calibration Curve for Multiclass Classification')
plt.legend(loc='upper left')
plt.show()

# %%
# Assuming predictions is a matrix of predicted probabilities for each class
prediction_confidences = np.max(predictions, axis=1)

# Plot histogram of prediction confidences
plt.figure(figsize=(8, 6))
plt.hist(prediction_confidences, bins=20, edgecolor='black')
plt.xlabel('Prediction Confidence')
plt.ylabel('Frequency')
plt.title('Distribution of Prediction Confidences')
plt.show()
