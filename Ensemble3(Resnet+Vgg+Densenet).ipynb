# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahamruf/Mosquito/blob/main/Ensemble3(Resnet%2BVgg%2BDensenet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Average
model_1 = load_model('/content/drive/MyDrive/resnetmosquito-05-0.8533.hdf5')
model_1 = Model(inputs=model_1.inputs,
                outputs=model_1.outputs,
                name='name_of_model_1')

# %%
model_2 = load_model('/content/drive/MyDrive/model2-05-0.5667.hdf5')
model_2 = Model(inputs=model_2.inputs,
                outputs=model_2.outputs,
                name='name_of_model_2')

# %%
model_3 = load_model('/content/drive/MyDrive/densemosquito-05-0.8800.hdf5')
model_3 = Model(inputs=model_3.inputs,
                outputs=model_3.outputs,
                name='name_of_model_3')

# %%
models = [model_1, model_2 ,model_3]
model_input = Input(shape=(299, 299, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = Average()(model_outputs)
ensemble_model = Model(inputs=model_input, outputs=ensemble_output, name='ensemble')

# %%
import tensorflow as tf
base_learning_rate = 0.001
ensemble_model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tensorflow import keras
import glob as gb
import pandas as pd
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU

# %%
IMG_SIZE = (299, 299) # resolution
directory = "/content/drive/MyDrive/zw4p9kj6nt-2"
BATCH_SIZE = 128
train_dataset = image_dataset_from_directory(directory,
                                             shuffle=True,
                                             labels='inferred',
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.1,
                                             subset='training',
                                             color_mode='rgb',
                                             seed=42)
validation_dataset = image_dataset_from_directory(directory,
                                             shuffle=True,
                                             labels='inferred',
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.1,
                                             subset='validation',
                                             color_mode='rgb',
                                             seed=42)
# Out:
# Found 1500 files belonging to 6 classes.
# Using 1350 files for training.
# Found 1500 files belonging to 6 classes.
# Using 150 files for validation.

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(directory):
    files = gb.glob(pathname=str(directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(13,7))
sns.barplot(x=[ "Aedes aegypti landing", "EUS", "Aedes aegypti smashed","Aedes albopictus smashed","Culex quinquefasciatus landing","Culex quinquefasciatus smashed"], y=Data_imbalance, palette="rocket")
plt.show()

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 6.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 6.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 6.0)
weight_for_3 = (1 / Data_imbalance[3]) * (total / 6.0)
weight_for_4 = (1 / Data_imbalance[3]) * (total / 6.0)
weight_for_5 = (1 / Data_imbalance[3]) * (total / 6.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3,4: weight_for_4,5: weight_for_5}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
print('Weight for class 4: {:.2f}'.format(weight_for_4))
print('Weight for class 5: {:.2f}'.format(weight_for_5))
# Out:
# Weight for class 0: 1.00
# Weight for class 1: 1.00
# Weight for class 2: 1.00
# Weight for class 3: 1.00
# Weight for class 4: 1.00
# Weight for class 5: 1.00

# %%
history = ensemble_model.fit(train_dataset , verbose=2 , epochs=100,class_weight=class_weight,
                               validation_data=validation_dataset , use_multiprocessing= True )
# Out:
# Epoch 1/100
# 11/11 - 189s - loss: 0.5200 - accuracy: 0.8815 - val_loss: 0.4958 - val_accuracy: 0.9000 - 189s/epoch - 17s/step
# Epoch 2/100
# 11/11 - 31s - loss: 0.4137 - accuracy: 0.9422 - val_loss: 0.4980 - val_accuracy: 0.8733 - 31s/epoch - 3s/step
# Epoch 3/100
# 11/11 - 31s - loss: 0.3725 - accuracy: 0.9607 - val_loss: 0.4471 - val_accuracy: 0.8933 - 31s/epoch - 3s/step
# Epoch 4/100
# 11/11 - 31s - loss: 0.3386 - accuracy: 0.9667 - val_loss: 0.4369 - val_accuracy: 0.8867 - 31s/epoch - 3s/step
# Epoch 5/100
# 11/11 - 31s - loss: 0.3138 - accuracy: 0.9689 - val_loss: 0.4169 - val_accuracy: 0.9000 - 31s/epoch - 3s/step
# Epoch 6/100
# 11/11 - 31s - loss: 0.2876 - accuracy: 0.9822 - val_loss: 0.4074 - val_accuracy: 0.8867 - 31s/epoch - 3s/step
# Epoch 7/100
# 11/11 - 31s - loss: 0.2998 - accuracy: 0.9578 - val_loss: 0.3953 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 8/100
# 11/11 - 31s - loss: 0.2674 - accuracy: 0.9778 - val_loss: 0.3534 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 9/100
# 11/11 - 31s - loss: 0.2476 - accuracy: 0.9830 - val_loss: 0.3335 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 10/100
# 11/11 - 31s - loss: 0.2382 - accuracy: 0.9844 - val_loss: 0.3388 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 11/100
# 11/11 - 31s - loss: 0.2434 - accuracy: 0.9696 - val_loss: 0.3193 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 12/100
# 11/11 - 31s - loss: 0.2366 - accuracy: 0.9696 - val_loss: 0.3282 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 13/100
# 11/11 - 31s - loss: 0.2471 - accuracy: 0.9689 - val_loss: 0.4096 - val_accuracy: 0.9000 - 31s/epoch - 3s/step
# Epoch 14/100
# 11/11 - 31s - loss: 0.2513 - accuracy: 0.9674 - val_loss: 0.3734 - val_accuracy: 0.8800 - 31s/epoch - 3s/step
# Epoch 15/100
# 11/11 - 31s - loss: 0.2337 - accuracy: 0.9667 - val_loss: 0.3078 - val_accuracy: 0.9467 - 31s/epoch - 3s/step
# Epoch 16/100
# 11/11 - 31s - loss: 0.2302 - accuracy: 0.9689 - val_loss: 0.3297 - val_accuracy: 0.9000 - 31s/epoch - 3s/step
# Epoch 17/100
# 11/11 - 31s - loss: 0.1997 - accuracy: 0.9793 - val_loss: 0.3294 - val_accuracy: 0.8867 - 31s/epoch - 3s/step
# Epoch 18/100
# 11/11 - 31s - loss: 0.2023 - accuracy: 0.9763 - val_loss: 0.2939 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 19/100
# 11/11 - 31s - loss: 0.1916 - accuracy: 0.9807 - val_loss: 0.2913 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 20/100
# 11/11 - 31s - loss: 0.1928 - accuracy: 0.9800 - val_loss: 0.3154 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 21/100
# 11/11 - 31s - loss: 0.1879 - accuracy: 0.9800 - val_loss: 0.3057 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 22/100
# 11/11 - 31s - loss: 0.1781 - accuracy: 0.9807 - val_loss: 0.3023 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 23/100
# 11/11 - 31s - loss: 0.1771 - accuracy: 0.9800 - val_loss: 0.2698 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 24/100
# 11/11 - 31s - loss: 0.1688 - accuracy: 0.9807 - val_loss: 0.2584 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 25/100
# 11/11 - 31s - loss: 0.1649 - accuracy: 0.9837 - val_loss: 0.2663 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 26/100
# 11/11 - 31s - loss: 0.1607 - accuracy: 0.9896 - val_loss: 0.2670 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 27/100
# 11/11 - 31s - loss: 0.1599 - accuracy: 0.9815 - val_loss: 0.2703 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 28/100
# 11/11 - 31s - loss: 0.1542 - accuracy: 0.9852 - val_loss: 0.2705 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 29/100
# 11/11 - 31s - loss: 0.1592 - accuracy: 0.9815 - val_loss: 0.2594 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 30/100
# 11/11 - 31s - loss: 0.1521 - accuracy: 0.9904 - val_loss: 0.2544 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 31/100
# 11/11 - 31s - loss: 0.1533 - accuracy: 0.9881 - val_loss: 0.2695 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 32/100
# 11/11 - 31s - loss: 0.1508 - accuracy: 0.9837 - val_loss: 0.2736 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 33/100
# 11/11 - 31s - loss: 0.1463 - accuracy: 0.9881 - val_loss: 0.2729 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 34/100
# 11/11 - 31s - loss: 0.1429 - accuracy: 0.9896 - val_loss: 0.2732 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 35/100
# 11/11 - 31s - loss: 0.1385 - accuracy: 0.9852 - val_loss: 0.2722 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 36/100
# 11/11 - 31s - loss: 0.1363 - accuracy: 0.9881 - val_loss: 0.2698 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 37/100
# 11/11 - 31s - loss: 0.1389 - accuracy: 0.9844 - val_loss: 0.2707 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 38/100
# 11/11 - 31s - loss: 0.1326 - accuracy: 0.9926 - val_loss: 0.2676 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 39/100
# 11/11 - 31s - loss: 0.1375 - accuracy: 0.9904 - val_loss: 0.2612 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 40/100
# 11/11 - 31s - loss: 0.1381 - accuracy: 0.9881 - val_loss: 0.2611 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 41/100
# 11/11 - 31s - loss: 0.1333 - accuracy: 0.9904 - val_loss: 0.2603 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 42/100
# 11/11 - 31s - loss: 0.1365 - accuracy: 0.9881 - val_loss: 0.2573 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 43/100
# 11/11 - 31s - loss: 0.1268 - accuracy: 0.9881 - val_loss: 0.2578 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 44/100
# 11/11 - 31s - loss: 0.1260 - accuracy: 0.9919 - val_loss: 0.2559 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 45/100
# 11/11 - 31s - loss: 0.1256 - accuracy: 0.9881 - val_loss: 0.2526 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 46/100
# 11/11 - 31s - loss: 0.1246 - accuracy: 0.9867 - val_loss: 0.2534 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 47/100
# 11/11 - 31s - loss: 0.1228 - accuracy: 0.9867 - val_loss: 0.2514 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 48/100
# 11/11 - 31s - loss: 0.1205 - accuracy: 0.9911 - val_loss: 0.2522 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 49/100
# 11/11 - 31s - loss: 0.1225 - accuracy: 0.9896 - val_loss: 0.2542 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 50/100
# 11/11 - 31s - loss: 0.1174 - accuracy: 0.9933 - val_loss: 0.2511 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 51/100
# 11/11 - 31s - loss: 0.1188 - accuracy: 0.9926 - val_loss: 0.2511 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 52/100
# 11/11 - 31s - loss: 0.1168 - accuracy: 0.9889 - val_loss: 0.2490 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 53/100
# 11/11 - 31s - loss: 0.1172 - accuracy: 0.9911 - val_loss: 0.2442 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 54/100
# 11/11 - 31s - loss: 0.1160 - accuracy: 0.9941 - val_loss: 0.2470 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 55/100
# 11/11 - 31s - loss: 0.1134 - accuracy: 0.9889 - val_loss: 0.2435 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 56/100
# 11/11 - 31s - loss: 0.1124 - accuracy: 0.9919 - val_loss: 0.2418 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 57/100
# 11/11 - 31s - loss: 0.1119 - accuracy: 0.9933 - val_loss: 0.2392 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 58/100
# 11/11 - 31s - loss: 0.1097 - accuracy: 0.9911 - val_loss: 0.2400 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 59/100
# 11/11 - 31s - loss: 0.1089 - accuracy: 0.9948 - val_loss: 0.2340 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 60/100
# 11/11 - 31s - loss: 0.1073 - accuracy: 0.9911 - val_loss: 0.2326 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 61/100
# 11/11 - 31s - loss: 0.1077 - accuracy: 0.9933 - val_loss: 0.2336 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 62/100
# 11/11 - 31s - loss: 0.1079 - accuracy: 0.9911 - val_loss: 0.2320 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 63/100
# 11/11 - 31s - loss: 0.1064 - accuracy: 0.9948 - val_loss: 0.2328 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 64/100
# 11/11 - 31s - loss: 0.1056 - accuracy: 0.9911 - val_loss: 0.2313 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 65/100
# 11/11 - 31s - loss: 0.1008 - accuracy: 0.9956 - val_loss: 0.2313 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 66/100
# 11/11 - 31s - loss: 0.1026 - accuracy: 0.9904 - val_loss: 0.2329 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 67/100
# 11/11 - 31s - loss: 0.1042 - accuracy: 0.9919 - val_loss: 0.2298 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 68/100
# 11/11 - 31s - loss: 0.1025 - accuracy: 0.9919 - val_loss: 0.2307 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 69/100
# 11/11 - 31s - loss: 0.1032 - accuracy: 0.9933 - val_loss: 0.2278 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 70/100
# 11/11 - 31s - loss: 0.0989 - accuracy: 0.9941 - val_loss: 0.2282 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 71/100
# 11/11 - 31s - loss: 0.0978 - accuracy: 0.9941 - val_loss: 0.2248 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 72/100
# 11/11 - 31s - loss: 0.0973 - accuracy: 0.9904 - val_loss: 0.2249 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 73/100
# 11/11 - 31s - loss: 0.0992 - accuracy: 0.9933 - val_loss: 0.2219 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 74/100
# 11/11 - 31s - loss: 0.0986 - accuracy: 0.9911 - val_loss: 0.2196 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 75/100
# 11/11 - 31s - loss: 0.0940 - accuracy: 0.9941 - val_loss: 0.2223 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 76/100
# 11/11 - 31s - loss: 0.0954 - accuracy: 0.9941 - val_loss: 0.2208 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 77/100
# 11/11 - 31s - loss: 0.0961 - accuracy: 0.9956 - val_loss: 0.2224 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 78/100
# 11/11 - 31s - loss: 0.0939 - accuracy: 0.9963 - val_loss: 0.2247 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 79/100
# 11/11 - 31s - loss: 0.0925 - accuracy: 0.9970 - val_loss: 0.2223 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 80/100
# 11/11 - 31s - loss: 0.0939 - accuracy: 0.9941 - val_loss: 0.2242 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 81/100
# 11/11 - 31s - loss: 0.0911 - accuracy: 0.9948 - val_loss: 0.2194 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 82/100
# 11/11 - 31s - loss: 0.0933 - accuracy: 0.9970 - val_loss: 0.2171 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 83/100
# 11/11 - 31s - loss: 0.0900 - accuracy: 0.9941 - val_loss: 0.2136 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 84/100
# 11/11 - 31s - loss: 0.0924 - accuracy: 0.9941 - val_loss: 0.2176 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 85/100
# 11/11 - 31s - loss: 0.0919 - accuracy: 0.9963 - val_loss: 0.2152 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 86/100
# 11/11 - 31s - loss: 0.0898 - accuracy: 0.9970 - val_loss: 0.2131 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 87/100
# 11/11 - 31s - loss: 0.0851 - accuracy: 0.9970 - val_loss: 0.2150 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 88/100
# 11/11 - 31s - loss: 0.0905 - accuracy: 0.9941 - val_loss: 0.2133 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 89/100
# 11/11 - 31s - loss: 0.0839 - accuracy: 0.9970 - val_loss: 0.2131 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 90/100
# 11/11 - 31s - loss: 0.0896 - accuracy: 0.9948 - val_loss: 0.2125 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 91/100
# 11/11 - 31s - loss: 0.0921 - accuracy: 0.9911 - val_loss: 0.2155 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 92/100
# 11/11 - 31s - loss: 0.0877 - accuracy: 0.9933 - val_loss: 0.2148 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 93/100
# 11/11 - 31s - loss: 0.0866 - accuracy: 0.9956 - val_loss: 0.2145 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 94/100
# 11/11 - 31s - loss: 0.0829 - accuracy: 0.9956 - val_loss: 0.2157 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 95/100
# 11/11 - 31s - loss: 0.0832 - accuracy: 0.9911 - val_loss: 0.2168 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 96/100
# 11/11 - 31s - loss: 0.0868 - accuracy: 0.9956 - val_loss: 0.2116 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 97/100
# 11/11 - 31s - loss: 0.0868 - accuracy: 0.9941 - val_loss: 0.2107 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 98/100
# 11/11 - 31s - loss: 0.0846 - accuracy: 0.9956 - val_loss: 0.2093 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 99/100
# 11/11 - 31s - loss: 0.0831 - accuracy: 0.9985 - val_loss: 0.2072 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 100/100
# 11/11 - 31s - loss: 0.0832 - accuracy: 0.9956 - val_loss: 0.2105 - val_accuracy: 0.9267 - 31s/epoch - 3s/step

# %%
ensemble_model.evaluate(validation_dataset , verbose = 1)
# Out:
# 2/2 [==============================] - 3s 438ms/step - loss: 0.2105 - accuracy: 0.9267
# [0.21049387753009796, 0.9266666769981384]

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Aedes  albopictus landing',
#  'Aedes aegypti landing',
#  'Aedes aegypti smashed',
#  'Aedes albopictus smashed',
#  'Culex quinquefasciatus landing',
#  'Culex quinquefasciatus smashed']

# %%
plt.figure(figsize=(20, 15))
for images, labels in train_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = ensemble_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in validation_dataset:
    predictions = ensemble_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves with different colors and line styles
plt.figure(figsize=(10, 8))

colors = plt.cm.rainbow(np.linspace(0, 1, len(class_names)))

for i, color in zip(range(len(class_names)), colors):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr, tpr,
        label=f'{class_names[i]} (AUC = {roc_auc:.2f})',
        color=color,
        linestyle='-',  # You can customize line styles here
        linewidth=2,  # You can customize line width here
        alpha=0.8  # You can customize transparency here
    )

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification')
plt.legend(loc='lower right')
plt.grid(True)  # Add a grid for better readability
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 16s 433ms/step
# 1/1 [==============================] - 4s 4s/step
# ROC AUC for Aedes  albopictus landing: 0.9520
# ROC AUC for Aedes aegypti landing: 0.9280
# ROC AUC for Aedes aegypti smashed: 0.9447
# ROC AUC for Aedes albopictus smashed: 0.9734
# ROC AUC for Culex quinquefasciatus landing: 0.9614
# ROC AUC for Culex quinquefasciatus smashed: 0.9762
#                                 precision    recall  f1-score   support
#
#      Aedes  albopictus landing       0.92      0.92      0.92        25
#          Aedes aegypti landing       0.88      0.88      0.88        25
#          Aedes aegypti smashed       0.88      0.91      0.89        23
#       Aedes albopictus smashed       0.93      0.96      0.95        27
# Culex quinquefasciatus landing       0.96      0.93      0.95        29
# Culex quinquefasciatus smashed       1.00      0.95      0.98        21
#
#                       accuracy                           0.93       150
#                      macro avg       0.93      0.93      0.93       150
#                   weighted avg       0.93      0.93      0.93       150

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Set a custom color palette (cividis is a good choice for accessibility)
custom_palette = sns.color_palette("cividis", as_cmap=True)

# Plot the confusion matrix as a heatmap with custom styling
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=custom_palette, xticklabels=class_names, yticklabels=class_names, cbar=False)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.title('Confusion Matrix for m (Ensemble model 1)', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
from sklearn.metrics import cohen_kappa_score

kappa = cohen_kappa_score(true_labels, predicted_labels)
print(f'Cohen\'s Kappa: {kappa:.4f}')
# Out:
# Cohen's Kappa: 0.9118

# %%
from sklearn.metrics import matthews_corrcoef
import numpy as np

# Assuming true_labels and predicted_labels are your multiclass labels
mcc_values = [matthews_corrcoef(true_labels == i, predicted_labels == i) for i in np.unique(true_labels)]

average_mcc = np.mean(mcc_values)
print(f'Average Matthews Correlation Coefficient for Multiclass: {average_mcc:.4f}')
# Out:
# Average Matthews Correlation Coefficient for Multiclass: 0.9125

# %%
from sklearn.metrics import precision_recall_curve

plt.figure(figsize=(10, 8))

for i, color in zip(range(len(class_names)), colors):
    precision, recall, _ = precision_recall_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    plt.plot(
        recall, precision,
        label=f'{class_names[i]}',
        color=color,
        linestyle='-',
        linewidth=2,
        alpha=0.8
    )

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves for Multiclass Fish Diseases Classification (Ensemble Model 1)')
plt.legend(loc='lower left')
plt.grid(True)
plt.show()

# %%
# Assuming predictions is a matrix of predicted probabilities for each class
prediction_confidences = np.max(predictions, axis=1)

# Plot histogram of prediction confidences
plt.figure(figsize=(8, 6))
plt.hist(prediction_confidences, bins=20, edgecolor='black')
plt.xlabel('Prediction Confidence')
plt.ylabel('Frequency')
plt.title('Distribution of Prediction Confidences')
plt.show()
