# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahamruf/Mosquito/blob/main/Ensemble_(Inception%2BResnet%2BDensenet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Average
model_1 = load_model('/content/drive/MyDrive/model-05-0.8400.hdf5')
model_1 = Model(inputs=model_1.inputs,
                outputs=model_1.outputs,
                name='name_of_model_1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model_2 = load_model('/content/drive/MyDrive/resnetmosquito-05-0.8533.hdf5')
model_2 = Model(inputs=model_2.inputs,
                outputs=model_2.outputs,
                name='name_of_model_2')

# %%
model_3 = load_model('/content/drive/MyDrive/densemosquito-05-0.8800.hdf5')
model_3 = Model(inputs=model_3.inputs,
                outputs=model_3.outputs,
                name='name_of_model_3')

# %%
models = [model_1, model_2 ,model_3]
model_input = Input(shape=(299, 299, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = Average()(model_outputs)
ensemble_model = Model(inputs=model_input, outputs=ensemble_output, name='ensemble')

# %%
import tensorflow as tf
base_learning_rate = 0.001
ensemble_model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tensorflow import keras
import glob as gb
import pandas as pd
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU

# %%
IMG_SIZE = (299, 299) # resolution
directory = "/content/drive/MyDrive/zw4p9kj6nt-2"
BATCH_SIZE = 128
train_dataset = image_dataset_from_directory(directory,
                                             shuffle=True,
                                             labels='inferred',
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.1,
                                             subset='training',
                                             color_mode='rgb',
                                             seed=42)
validation_dataset = image_dataset_from_directory(directory,
                                             shuffle=True,
                                             labels='inferred',
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.1,
                                             subset='validation',
                                             color_mode='rgb',
                                             seed=42)
# Out:
# Found 1500 files belonging to 6 classes.
# Using 1350 files for training.
# Found 1500 files belonging to 6 classes.
# Using 150 files for validation.

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(directory):
    files = gb.glob(pathname=str(directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(13,7))
sns.barplot(x=[ "Aedes aegypti landing", "EUS", "Aedes aegypti smashed","Aedes albopictus smashed","Culex quinquefasciatus landing","Culex quinquefasciatus smashed"], y=Data_imbalance, palette="rocket")
plt.show()

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 6.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 6.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 6.0)
weight_for_3 = (1 / Data_imbalance[3]) * (total / 6.0)
weight_for_4 = (1 / Data_imbalance[3]) * (total / 6.0)
weight_for_5 = (1 / Data_imbalance[3]) * (total / 6.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3,4: weight_for_4,5: weight_for_5}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
print('Weight for class 4: {:.2f}'.format(weight_for_4))
print('Weight for class 5: {:.2f}'.format(weight_for_5))
# Out:
# Weight for class 0: 1.00
# Weight for class 1: 1.00
# Weight for class 2: 1.00
# Weight for class 3: 1.00
# Weight for class 4: 1.00
# Weight for class 5: 1.00

# %%
history = ensemble_model.fit(train_dataset , verbose=2 , epochs=100,class_weight=class_weight,
                               validation_data=validation_dataset , use_multiprocessing= True )
# Out:
# Epoch 1/100
# 11/11 - 179s - loss: 0.4059 - accuracy: 0.9015 - val_loss: 0.4191 - val_accuracy: 0.9067 - 179s/epoch - 16s/step
# Epoch 2/100
# 11/11 - 25s - loss: 0.2551 - accuracy: 0.9622 - val_loss: 0.3297 - val_accuracy: 0.9267 - 25s/epoch - 2s/step
# Epoch 3/100
# 11/11 - 25s - loss: 0.2056 - accuracy: 0.9800 - val_loss: 0.3396 - val_accuracy: 0.9133 - 25s/epoch - 2s/step
# Epoch 4/100
# 11/11 - 25s - loss: 0.1739 - accuracy: 0.9852 - val_loss: 0.3497 - val_accuracy: 0.8867 - 25s/epoch - 2s/step
# Epoch 5/100
# 11/11 - 25s - loss: 0.1597 - accuracy: 0.9867 - val_loss: 0.2778 - val_accuracy: 0.9333 - 25s/epoch - 2s/step
# Epoch 6/100
# 11/11 - 25s - loss: 0.1322 - accuracy: 0.9963 - val_loss: 0.2909 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 7/100
# 11/11 - 25s - loss: 0.1225 - accuracy: 0.9963 - val_loss: 0.2553 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 8/100
# 11/11 - 25s - loss: 0.1120 - accuracy: 0.9963 - val_loss: 0.2411 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 9/100
# 11/11 - 25s - loss: 0.1102 - accuracy: 0.9978 - val_loss: 0.2593 - val_accuracy: 0.9200 - 25s/epoch - 2s/step
# Epoch 10/100
# 11/11 - 25s - loss: 0.1026 - accuracy: 0.9963 - val_loss: 0.2386 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 11/100
# 11/11 - 25s - loss: 0.0957 - accuracy: 0.9985 - val_loss: 0.2448 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 12/100
# 11/11 - 25s - loss: 0.0930 - accuracy: 0.9978 - val_loss: 0.2425 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 13/100
# 11/11 - 25s - loss: 0.0944 - accuracy: 0.9963 - val_loss: 0.2587 - val_accuracy: 0.9333 - 25s/epoch - 2s/step
# Epoch 14/100
# 11/11 - 25s - loss: 0.0935 - accuracy: 0.9970 - val_loss: 0.2311 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 15/100
# 11/11 - 25s - loss: 0.0864 - accuracy: 0.9970 - val_loss: 0.2360 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 16/100
# 11/11 - 25s - loss: 0.0837 - accuracy: 0.9956 - val_loss: 0.2568 - val_accuracy: 0.9333 - 25s/epoch - 2s/step
# Epoch 17/100
# 11/11 - 25s - loss: 0.0891 - accuracy: 0.9956 - val_loss: 0.2170 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 18/100
# 11/11 - 25s - loss: 0.0799 - accuracy: 0.9985 - val_loss: 0.2341 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 19/100
# 11/11 - 25s - loss: 0.0805 - accuracy: 0.9978 - val_loss: 0.2056 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 20/100
# 11/11 - 25s - loss: 0.0749 - accuracy: 0.9993 - val_loss: 0.2229 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 21/100
# 11/11 - 25s - loss: 0.0701 - accuracy: 0.9985 - val_loss: 0.2089 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 22/100
# 11/11 - 25s - loss: 0.0717 - accuracy: 0.9985 - val_loss: 0.2276 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 23/100
# 11/11 - 25s - loss: 0.0721 - accuracy: 0.9978 - val_loss: 0.2151 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 24/100
# 11/11 - 25s - loss: 0.0698 - accuracy: 0.9985 - val_loss: 0.2133 - val_accuracy: 0.9333 - 25s/epoch - 2s/step
# Epoch 25/100
# 11/11 - 25s - loss: 0.0684 - accuracy: 0.9985 - val_loss: 0.2163 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 26/100
# 11/11 - 25s - loss: 0.0663 - accuracy: 0.9978 - val_loss: 0.2260 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 27/100
# 11/11 - 25s - loss: 0.0729 - accuracy: 0.9978 - val_loss: 0.2241 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 28/100
# 11/11 - 25s - loss: 0.0652 - accuracy: 0.9985 - val_loss: 0.2357 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 29/100
# 11/11 - 25s - loss: 0.0688 - accuracy: 0.9978 - val_loss: 0.2211 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 30/100
# 11/11 - 25s - loss: 0.0622 - accuracy: 0.9993 - val_loss: 0.2067 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 31/100
# 11/11 - 25s - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 32/100
# 11/11 - 25s - loss: 0.0586 - accuracy: 1.0000 - val_loss: 0.2246 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 33/100
# 11/11 - 25s - loss: 0.0662 - accuracy: 0.9993 - val_loss: 0.2098 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 34/100
# 11/11 - 25s - loss: 0.0641 - accuracy: 1.0000 - val_loss: 0.2153 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 35/100
# 11/11 - 25s - loss: 0.0597 - accuracy: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 36/100
# 11/11 - 25s - loss: 0.0765 - accuracy: 0.9978 - val_loss: 0.2285 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 37/100
# 11/11 - 25s - loss: 0.0635 - accuracy: 0.9993 - val_loss: 0.2148 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 38/100
# 11/11 - 25s - loss: 0.0730 - accuracy: 0.9985 - val_loss: 0.2504 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 39/100
# 11/11 - 25s - loss: 0.0619 - accuracy: 0.9970 - val_loss: 0.2211 - val_accuracy: 0.9267 - 25s/epoch - 2s/step
# Epoch 40/100
# 11/11 - 25s - loss: 0.0703 - accuracy: 0.9963 - val_loss: 0.2689 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 41/100
# 11/11 - 25s - loss: 0.0941 - accuracy: 0.9985 - val_loss: 0.2390 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 42/100
# 11/11 - 25s - loss: 0.0801 - accuracy: 0.9956 - val_loss: 0.2319 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 43/100
# 11/11 - 25s - loss: 0.0764 - accuracy: 0.9926 - val_loss: 0.2361 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 44/100
# 11/11 - 25s - loss: 0.0659 - accuracy: 0.9978 - val_loss: 0.2433 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 45/100
# 11/11 - 25s - loss: 0.0673 - accuracy: 0.9963 - val_loss: 0.1936 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 46/100
# 11/11 - 25s - loss: 0.0585 - accuracy: 0.9993 - val_loss: 0.2185 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 47/100
# 11/11 - 25s - loss: 0.0572 - accuracy: 0.9985 - val_loss: 0.2184 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 48/100
# 11/11 - 25s - loss: 0.0625 - accuracy: 0.9978 - val_loss: 0.2128 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 49/100
# 11/11 - 25s - loss: 0.0675 - accuracy: 0.9978 - val_loss: 0.2351 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 50/100
# 11/11 - 25s - loss: 0.0638 - accuracy: 0.9963 - val_loss: 0.2157 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 51/100
# 11/11 - 25s - loss: 0.0590 - accuracy: 0.9985 - val_loss: 0.2100 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 52/100
# 11/11 - 25s - loss: 0.0561 - accuracy: 0.9985 - val_loss: 0.2155 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 53/100
# 11/11 - 25s - loss: 0.0594 - accuracy: 0.9963 - val_loss: 0.2301 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 54/100
# 11/11 - 25s - loss: 0.0842 - accuracy: 0.9963 - val_loss: 0.1968 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 55/100
# 11/11 - 25s - loss: 0.0584 - accuracy: 0.9956 - val_loss: 0.2219 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 56/100
# 11/11 - 25s - loss: 0.0637 - accuracy: 0.9978 - val_loss: 0.2299 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 57/100
# 11/11 - 25s - loss: 0.0754 - accuracy: 0.9941 - val_loss: 0.2330 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 58/100
# 11/11 - 25s - loss: 0.0560 - accuracy: 0.9993 - val_loss: 0.2220 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 59/100
# 11/11 - 25s - loss: 0.0502 - accuracy: 0.9970 - val_loss: 0.2138 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 60/100
# 11/11 - 25s - loss: 0.0514 - accuracy: 0.9978 - val_loss: 0.2228 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 61/100
# 11/11 - 25s - loss: 0.0496 - accuracy: 0.9985 - val_loss: 0.2025 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 62/100
# 11/11 - 25s - loss: 0.0510 - accuracy: 0.9993 - val_loss: 0.2071 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 63/100
# 11/11 - 25s - loss: 0.0461 - accuracy: 1.0000 - val_loss: 0.2158 - val_accuracy: 0.9200 - 25s/epoch - 2s/step
# Epoch 64/100
# 11/11 - 25s - loss: 0.0459 - accuracy: 0.9993 - val_loss: 0.2290 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 65/100
# 11/11 - 25s - loss: 0.0480 - accuracy: 0.9985 - val_loss: 0.2117 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 66/100
# 11/11 - 25s - loss: 0.0431 - accuracy: 0.9993 - val_loss: 0.2246 - val_accuracy: 0.9533 - 25s/epoch - 2s/step
# Epoch 67/100
# 11/11 - 25s - loss: 0.0442 - accuracy: 0.9993 - val_loss: 0.2184 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 68/100
# 11/11 - 25s - loss: 0.0593 - accuracy: 0.9963 - val_loss: 0.2238 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 69/100
# 11/11 - 25s - loss: 0.0485 - accuracy: 0.9985 - val_loss: 0.2168 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 70/100
# 11/11 - 25s - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.2056 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 71/100
# 11/11 - 25s - loss: 0.0663 - accuracy: 0.9978 - val_loss: 0.2149 - val_accuracy: 0.9333 - 25s/epoch - 2s/step
# Epoch 72/100
# 11/11 - 25s - loss: 0.0487 - accuracy: 0.9985 - val_loss: 0.2146 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 73/100
# 11/11 - 25s - loss: 0.0554 - accuracy: 0.9993 - val_loss: 0.2284 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 74/100
# 11/11 - 25s - loss: 0.0565 - accuracy: 0.9956 - val_loss: 0.2077 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 75/100
# 11/11 - 25s - loss: 0.0701 - accuracy: 0.9948 - val_loss: 0.2242 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 76/100
# 11/11 - 25s - loss: 0.1197 - accuracy: 0.9904 - val_loss: 0.2592 - val_accuracy: 0.9267 - 25s/epoch - 2s/step
# Epoch 77/100
# 11/11 - 25s - loss: 0.0972 - accuracy: 0.9926 - val_loss: 0.2625 - val_accuracy: 0.9333 - 25s/epoch - 2s/step
# Epoch 78/100
# 11/11 - 25s - loss: 0.1094 - accuracy: 0.9926 - val_loss: 0.2120 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 79/100
# 11/11 - 25s - loss: 0.0823 - accuracy: 0.9956 - val_loss: 0.2172 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 80/100
# 11/11 - 25s - loss: 0.1245 - accuracy: 0.9919 - val_loss: 0.2853 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 81/100
# 11/11 - 25s - loss: 0.1336 - accuracy: 0.9985 - val_loss: 0.2356 - val_accuracy: 0.9267 - 25s/epoch - 2s/step
# Epoch 82/100
# 11/11 - 25s - loss: 0.0933 - accuracy: 0.9963 - val_loss: 0.2407 - val_accuracy: 0.9600 - 25s/epoch - 2s/step
# Epoch 83/100
# 11/11 - 25s - loss: 0.1326 - accuracy: 0.9948 - val_loss: 0.4833 - val_accuracy: 0.9200 - 25s/epoch - 2s/step
# Epoch 84/100
# 11/11 - 25s - loss: 0.3818 - accuracy: 0.9948 - val_loss: 0.5136 - val_accuracy: 0.9267 - 25s/epoch - 2s/step
# Epoch 85/100
# 11/11 - 25s - loss: 0.3596 - accuracy: 0.9963 - val_loss: 0.4672 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 86/100
# 11/11 - 25s - loss: 0.3352 - accuracy: 0.9933 - val_loss: 0.4399 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 87/100
# 11/11 - 25s - loss: 0.3472 - accuracy: 0.9948 - val_loss: 0.5268 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 88/100
# 11/11 - 25s - loss: 0.3895 - accuracy: 0.9970 - val_loss: 0.5246 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 89/100
# 11/11 - 25s - loss: 0.3926 - accuracy: 0.9963 - val_loss: 0.5202 - val_accuracy: 0.9333 - 25s/epoch - 2s/step
# Epoch 90/100
# 11/11 - 25s - loss: 0.3888 - accuracy: 0.9985 - val_loss: 0.5335 - val_accuracy: 0.9267 - 25s/epoch - 2s/step
# Epoch 91/100
# 11/11 - 25s - loss: 0.3957 - accuracy: 0.9978 - val_loss: 0.5218 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 92/100
# 11/11 - 25s - loss: 0.3893 - accuracy: 0.9948 - val_loss: 0.5248 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 93/100
# 11/11 - 25s - loss: 0.3934 - accuracy: 0.9978 - val_loss: 0.5238 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 94/100
# 11/11 - 25s - loss: 0.3884 - accuracy: 0.9963 - val_loss: 0.5191 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 95/100
# 11/11 - 25s - loss: 0.3891 - accuracy: 0.9963 - val_loss: 0.5148 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 96/100
# 11/11 - 25s - loss: 0.3903 - accuracy: 0.9985 - val_loss: 0.5225 - val_accuracy: 0.9467 - 25s/epoch - 2s/step
# Epoch 97/100
# 11/11 - 25s - loss: 0.3913 - accuracy: 0.9963 - val_loss: 0.5300 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 98/100
# 11/11 - 25s - loss: 0.3936 - accuracy: 0.9956 - val_loss: 0.5340 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 99/100
# 11/11 - 25s - loss: 0.3906 - accuracy: 0.9956 - val_loss: 0.5128 - val_accuracy: 0.9400 - 25s/epoch - 2s/step
# Epoch 100/100
# 11/11 - 25s - loss: 0.3848 - accuracy: 0.9978 - val_loss: 0.5245 - val_accuracy: 0.9333 - 25s/epoch - 2s/step

# %%
ensemble_model.evaluate(validation_dataset , verbose = 1)
# Out:
# 2/2 [==============================] - 2s 357ms/step - loss: 0.5245 - accuracy: 0.9333
# [0.5244967937469482, 0.9333333373069763]

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Aedes  albopictus landing',
#  'Aedes aegypti landing',
#  'Aedes aegypti smashed',
#  'Aedes albopictus smashed',
#  'Culex quinquefasciatus landing',
#  'Culex quinquefasciatus smashed']

# %%
plt.figure(figsize=(20, 15))
for images, labels in train_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = ensemble_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 6s 6s/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in validation_dataset:
    predictions = ensemble_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves with different colors and line styles
plt.figure(figsize=(10, 8))

colors = plt.cm.rainbow(np.linspace(0, 1, len(class_names)))

for i, color in zip(range(len(class_names)), colors):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr, tpr,
        label=f'{class_names[i]} (AUC = {roc_auc:.2f})',
        color=color,
        linestyle='-',  # You can customize line styles here
        linewidth=2,  # You can customize line width here
        alpha=0.8  # You can customize transparency here
    )

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification')
plt.legend(loc='lower right')
plt.grid(True)  # Add a grid for better readability
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 14s 421ms/step
# 1/1 [==============================] - 4s 4s/step
# ROC AUC for Aedes  albopictus landing: 0.9560
# ROC AUC for Aedes aegypti landing: 0.9760
# ROC AUC for Aedes aegypti smashed: 0.9091
# ROC AUC for Aedes albopictus smashed: 0.9919
# ROC AUC for Culex quinquefasciatus landing: 0.9614
# ROC AUC for Culex quinquefasciatus smashed: 0.9607
#                                 precision    recall  f1-score   support
#
#      Aedes  albopictus landing       0.96      0.92      0.94        25
#          Aedes aegypti landing       0.96      0.96      0.96        25
#          Aedes aegypti smashed       0.95      0.83      0.88        23
#       Aedes albopictus smashed       0.93      1.00      0.96        27
# Culex quinquefasciatus landing       0.96      0.93      0.95        29
# Culex quinquefasciatus smashed       0.83      0.95      0.89        21
#
#                       accuracy                           0.93       150
#                      macro avg       0.93      0.93      0.93       150
#                   weighted avg       0.94      0.93      0.93       150

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Set a custom color palette (cividis is a good choice for accessibility)
custom_palette = sns.color_palette("cividis", as_cmap=True)

# Plot the confusion matrix as a heatmap with custom styling
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=custom_palette, xticklabels=class_names, yticklabels=class_names, cbar=False)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.title('Confusion Matrix for m (Ensemble model 1)', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
from sklearn.metrics import cohen_kappa_score

kappa = cohen_kappa_score(true_labels, predicted_labels)
print(f'Cohen\'s Kappa: {kappa:.4f}')
# Out:
# Cohen's Kappa: 0.9199

# %%
from sklearn.metrics import matthews_corrcoef
import numpy as np

# Assuming true_labels and predicted_labels are your multiclass labels
mcc_values = [matthews_corrcoef(true_labels == i, predicted_labels == i) for i in np.unique(true_labels)]

average_mcc = np.mean(mcc_values)
print(f'Average Matthews Correlation Coefficient for Multiclass: {average_mcc:.4f}')
# Out:
# Average Matthews Correlation Coefficient for Multiclass: 0.9184

# %%
from sklearn.metrics import precision_recall_curve

plt.figure(figsize=(10, 8))

for i, color in zip(range(len(class_names)), colors):
    precision, recall, _ = precision_recall_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    plt.plot(
        recall, precision,
        label=f'{class_names[i]}',
        color=color,
        linestyle='-',
        linewidth=2,
        alpha=0.8
    )

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves for Multiclass Fish Diseases Classification (Ensemble Model 1)')
plt.legend(loc='lower left')
plt.grid(True)
plt.show()

# %%
from sklearn.calibration import calibration_curve

plt.figure(figsize=(8, 8))

for i in range(len(class_names)):
    prob_true, prob_pred = calibration_curve(true_labels_bin[:, i], predicted_labels_bin[:, i], n_bins=10, strategy='uniform')
    plt.plot(prob_pred, prob_true, marker='o', label=f'{class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('Mean Predicted Probability')
plt.ylabel('Fraction of Positives')
plt.title('Calibration Curve for Multiclass Classification')
plt.legend(loc='upper left')
plt.show()

# %%
# Assuming predictions is a matrix of predicted probabilities for each class
prediction_confidences = np.max(predictions, axis=1)

# Plot histogram of prediction confidences
plt.figure(figsize=(8, 6))
plt.hist(prediction_confidences, bins=20, edgecolor='black')
plt.xlabel('Prediction Confidence')
plt.ylabel('Frequency')
plt.title('Distribution of Prediction Confidences')
plt.show()
