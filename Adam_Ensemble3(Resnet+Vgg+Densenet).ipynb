# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahamruf/Mosquito/blob/main/Adam_Ensemble3(Resnet%2BVgg%2BDensenet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Average
model_1 = load_model('/content/drive/MyDrive/resnetmosquito-05-0.8533.hdf5')
model_1 = Model(inputs=model_1.inputs,
                outputs=model_1.outputs,
                name='name_of_model_1')

# %%
model_2 = load_model('/content/drive/MyDrive/model2-05-0.5667.hdf5')
model_2 = Model(inputs=model_2.inputs,
                outputs=model_2.outputs,
                name='name_of_model_2')

# %%
model_3 = load_model('/content/drive/MyDrive/densemosquito-05-0.8800.hdf5')
model_3 = Model(inputs=model_3.inputs,
                outputs=model_3.outputs,
                name='name_of_model_3')

# %%
models = [model_1, model_2 ,model_3]
model_input = Input(shape=(299, 299, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = Average()(model_outputs)
ensemble_model = Model(inputs=model_input, outputs=ensemble_output, name='ensemble')

# %%
import tensorflow as tf
base_learning_rate = 0.001
ensemble_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tensorflow import keras
import glob as gb
import pandas as pd
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU

# %%
IMG_SIZE = (299, 299)  # resolution
directory = "/content/drive/MyDrive/zw4p9kj6nt-2"
BATCH_SIZE = 128

# Training dataset
train_dataset = image_dataset_from_directory(directory,
                                             shuffle=True,
                                             labels='inferred',
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.1,
                                             subset='training',
                                             color_mode='rgb',
                                             seed=42)

# Validation dataset
validation_dataset = image_dataset_from_directory(directory,
                                                  shuffle=True,
                                                  labels='inferred',
                                                  batch_size=BATCH_SIZE,
                                                  image_size=IMG_SIZE,
                                                  validation_split=0.1,
                                                  subset='validation',
                                                  color_mode='rgb',
                                                  seed=42)
# Out:
# Found 1500 files belonging to 6 classes.
# Using 1350 files for training.
# Found 1500 files belonging to 6 classes.
# Using 150 files for validation.

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(directory):
    files = gb.glob(pathname=str(directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
plt.figure(figsize=(13,7))
sns.barplot(x=[ "Aedes aegypti landing", "EUS", "Aedes aegypti smashed","Aedes albopictus smashed","Culex quinquefasciatus landing","Culex quinquefasciatus smashed"], y=Data_imbalance, palette="rocket")
plt.show()

# %%
total = 0
for i in range(0,len(Data_imbalance)) :
    total +=Data_imbalance[i]

weight_for_0 = (1 / Data_imbalance[0]) * (total / 6.0)
weight_for_1 = (1 / Data_imbalance[1]) * (total / 6.0)
weight_for_2 = (1 / Data_imbalance[2]) * (total / 6.0)
weight_for_3 = (1 / Data_imbalance[3]) * (total / 6.0)
weight_for_4 = (1 / Data_imbalance[3]) * (total / 6.0)
weight_for_5 = (1 / Data_imbalance[3]) * (total / 6.0)

class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2, 3: weight_for_3,4: weight_for_4,5: weight_for_5}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
print('Weight for class 2: {:.2f}'.format(weight_for_2))
print('Weight for class 3: {:.2f}'.format(weight_for_3))
print('Weight for class 4: {:.2f}'.format(weight_for_4))
print('Weight for class 5: {:.2f}'.format(weight_for_5))
# Out:
# Weight for class 0: 1.00
# Weight for class 1: 1.00
# Weight for class 2: 1.00
# Weight for class 3: 1.00
# Weight for class 4: 1.00
# Weight for class 5: 1.00

# %%
history = ensemble_model.fit(train_dataset , verbose=2 , epochs=100,class_weight=class_weight,
                               validation_data=validation_dataset , use_multiprocessing= True )
# Out:
# Epoch 1/100
# 11/11 - 118s - loss: 0.5676 - accuracy: 0.8622 - val_loss: 0.5970 - val_accuracy: 0.8333 - 118s/epoch - 11s/step
# Epoch 2/100
# 11/11 - 29s - loss: 0.5041 - accuracy: 0.8874 - val_loss: 0.5010 - val_accuracy: 0.8533 - 29s/epoch - 3s/step
# Epoch 3/100
# 11/11 - 29s - loss: 0.3997 - accuracy: 0.9326 - val_loss: 0.4530 - val_accuracy: 0.9000 - 29s/epoch - 3s/step
# Epoch 4/100
# 11/11 - 29s - loss: 0.3626 - accuracy: 0.9481 - val_loss: 0.4396 - val_accuracy: 0.8733 - 29s/epoch - 3s/step
# Epoch 5/100
# 11/11 - 30s - loss: 0.3276 - accuracy: 0.9607 - val_loss: 0.4311 - val_accuracy: 0.8733 - 30s/epoch - 3s/step
# Epoch 6/100
# 11/11 - 30s - loss: 0.3116 - accuracy: 0.9644 - val_loss: 0.4186 - val_accuracy: 0.8867 - 30s/epoch - 3s/step
# Epoch 7/100
# 11/11 - 30s - loss: 0.2905 - accuracy: 0.9637 - val_loss: 0.4166 - val_accuracy: 0.8867 - 30s/epoch - 3s/step
# Epoch 8/100
# 11/11 - 30s - loss: 0.3114 - accuracy: 0.9452 - val_loss: 0.3653 - val_accuracy: 0.9200 - 30s/epoch - 3s/step
# Epoch 9/100
# 11/11 - 30s - loss: 0.2740 - accuracy: 0.9674 - val_loss: 0.3634 - val_accuracy: 0.9067 - 30s/epoch - 3s/step
# Epoch 10/100
# 11/11 - 30s - loss: 0.2565 - accuracy: 0.9637 - val_loss: 0.3670 - val_accuracy: 0.9133 - 30s/epoch - 3s/step
# Epoch 11/100
# 11/11 - 31s - loss: 0.2507 - accuracy: 0.9696 - val_loss: 0.3399 - val_accuracy: 0.8867 - 31s/epoch - 3s/step
# Epoch 12/100
# 11/11 - 31s - loss: 0.2270 - accuracy: 0.9748 - val_loss: 0.3436 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 13/100
# 11/11 - 31s - loss: 0.2277 - accuracy: 0.9785 - val_loss: 0.3275 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 14/100
# 11/11 - 31s - loss: 0.2196 - accuracy: 0.9756 - val_loss: 0.3280 - val_accuracy: 0.9000 - 31s/epoch - 3s/step
# Epoch 15/100
# 11/11 - 31s - loss: 0.2135 - accuracy: 0.9748 - val_loss: 0.3068 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 16/100
# 11/11 - 31s - loss: 0.2075 - accuracy: 0.9830 - val_loss: 0.3273 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 17/100
# 11/11 - 31s - loss: 0.2020 - accuracy: 0.9756 - val_loss: 0.3089 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 18/100
# 11/11 - 31s - loss: 0.1927 - accuracy: 0.9763 - val_loss: 0.3129 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 19/100
# 11/11 - 31s - loss: 0.1962 - accuracy: 0.9785 - val_loss: 0.3220 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 20/100
# 11/11 - 31s - loss: 0.1962 - accuracy: 0.9756 - val_loss: 0.3166 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 21/100
# 11/11 - 31s - loss: 0.1858 - accuracy: 0.9807 - val_loss: 0.3092 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 22/100
# 11/11 - 31s - loss: 0.1803 - accuracy: 0.9807 - val_loss: 0.2971 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 23/100
# 11/11 - 31s - loss: 0.1781 - accuracy: 0.9815 - val_loss: 0.2873 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 24/100
# 11/11 - 31s - loss: 0.1746 - accuracy: 0.9844 - val_loss: 0.2886 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 25/100
# 11/11 - 31s - loss: 0.1661 - accuracy: 0.9830 - val_loss: 0.2646 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 26/100
# 11/11 - 31s - loss: 0.1635 - accuracy: 0.9867 - val_loss: 0.2620 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 27/100
# 11/11 - 31s - loss: 0.1643 - accuracy: 0.9881 - val_loss: 0.3057 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 28/100
# 11/11 - 31s - loss: 0.1626 - accuracy: 0.9837 - val_loss: 0.2971 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 29/100
# 11/11 - 31s - loss: 0.1579 - accuracy: 0.9830 - val_loss: 0.2771 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 30/100
# 11/11 - 31s - loss: 0.1569 - accuracy: 0.9874 - val_loss: 0.2739 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 31/100
# 11/11 - 31s - loss: 0.1510 - accuracy: 0.9837 - val_loss: 0.2777 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 32/100
# 11/11 - 31s - loss: 0.1579 - accuracy: 0.9852 - val_loss: 0.2795 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 33/100
# 11/11 - 31s - loss: 0.1610 - accuracy: 0.9800 - val_loss: 0.2680 - val_accuracy: 0.9000 - 31s/epoch - 3s/step
# Epoch 34/100
# 11/11 - 31s - loss: 0.1610 - accuracy: 0.9785 - val_loss: 0.2765 - val_accuracy: 0.8933 - 31s/epoch - 3s/step
# Epoch 35/100
# 11/11 - 31s - loss: 0.1512 - accuracy: 0.9830 - val_loss: 0.2519 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 36/100
# 11/11 - 31s - loss: 0.1494 - accuracy: 0.9830 - val_loss: 0.2572 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 37/100
# 11/11 - 31s - loss: 0.1569 - accuracy: 0.9822 - val_loss: 0.2780 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 38/100
# 11/11 - 31s - loss: 0.1897 - accuracy: 0.9733 - val_loss: 0.3112 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 39/100
# 11/11 - 31s - loss: 0.1691 - accuracy: 0.9763 - val_loss: 0.2549 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 40/100
# 11/11 - 31s - loss: 0.1554 - accuracy: 0.9844 - val_loss: 0.2855 - val_accuracy: 0.8867 - 31s/epoch - 3s/step
# Epoch 41/100
# 11/11 - 31s - loss: 0.1519 - accuracy: 0.9785 - val_loss: 0.2747 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 42/100
# 11/11 - 31s - loss: 0.1389 - accuracy: 0.9896 - val_loss: 0.2460 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 43/100
# 11/11 - 31s - loss: 0.1451 - accuracy: 0.9881 - val_loss: 0.2762 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 44/100
# 11/11 - 31s - loss: 0.1718 - accuracy: 0.9689 - val_loss: 0.2731 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 45/100
# 11/11 - 31s - loss: 0.1423 - accuracy: 0.9830 - val_loss: 0.2542 - val_accuracy: 0.9000 - 31s/epoch - 3s/step
# Epoch 46/100
# 11/11 - 31s - loss: 0.1352 - accuracy: 0.9859 - val_loss: 0.2721 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 47/100
# 11/11 - 31s - loss: 0.1443 - accuracy: 0.9756 - val_loss: 0.2681 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 48/100
# 11/11 - 31s - loss: 0.1357 - accuracy: 0.9837 - val_loss: 0.2574 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 49/100
# 11/11 - 31s - loss: 0.1375 - accuracy: 0.9844 - val_loss: 0.2491 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 50/100
# 11/11 - 31s - loss: 0.1172 - accuracy: 0.9941 - val_loss: 0.2564 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 51/100
# 11/11 - 31s - loss: 0.1281 - accuracy: 0.9904 - val_loss: 0.2514 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 52/100
# 11/11 - 31s - loss: 0.1276 - accuracy: 0.9881 - val_loss: 0.2625 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 53/100
# 11/11 - 31s - loss: 0.1261 - accuracy: 0.9852 - val_loss: 0.2449 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 54/100
# 11/11 - 31s - loss: 0.1176 - accuracy: 0.9941 - val_loss: 0.2351 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 55/100
# 11/11 - 31s - loss: 0.1130 - accuracy: 0.9911 - val_loss: 0.2360 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 56/100
# 11/11 - 31s - loss: 0.1159 - accuracy: 0.9881 - val_loss: 0.2509 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 57/100
# 11/11 - 31s - loss: 0.1149 - accuracy: 0.9933 - val_loss: 0.2434 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 58/100
# 11/11 - 31s - loss: 0.1136 - accuracy: 0.9911 - val_loss: 0.2269 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 59/100
# 11/11 - 31s - loss: 0.1111 - accuracy: 0.9889 - val_loss: 0.2313 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 60/100
# 11/11 - 31s - loss: 0.1079 - accuracy: 0.9926 - val_loss: 0.2308 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 61/100
# 11/11 - 31s - loss: 0.1075 - accuracy: 0.9933 - val_loss: 0.2280 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 62/100
# 11/11 - 31s - loss: 0.1105 - accuracy: 0.9933 - val_loss: 0.2456 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 63/100
# 11/11 - 31s - loss: 0.1130 - accuracy: 0.9919 - val_loss: 0.2367 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 64/100
# 11/11 - 31s - loss: 0.1061 - accuracy: 0.9941 - val_loss: 0.2251 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 65/100
# 11/11 - 31s - loss: 0.1124 - accuracy: 0.9889 - val_loss: 0.2406 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 66/100
# 11/11 - 31s - loss: 0.1128 - accuracy: 0.9926 - val_loss: 0.2569 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 67/100
# 11/11 - 31s - loss: 0.1089 - accuracy: 0.9941 - val_loss: 0.2815 - val_accuracy: 0.8933 - 31s/epoch - 3s/step
# Epoch 68/100
# 11/11 - 31s - loss: 0.1198 - accuracy: 0.9830 - val_loss: 0.2685 - val_accuracy: 0.9000 - 31s/epoch - 3s/step
# Epoch 69/100
# 11/11 - 31s - loss: 0.1577 - accuracy: 0.9793 - val_loss: 0.2878 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 70/100
# 11/11 - 31s - loss: 0.1498 - accuracy: 0.9793 - val_loss: 0.3245 - val_accuracy: 0.8933 - 31s/epoch - 3s/step
# Epoch 71/100
# 11/11 - 31s - loss: 0.1287 - accuracy: 0.9867 - val_loss: 0.2429 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 72/100
# 11/11 - 31s - loss: 0.1175 - accuracy: 0.9911 - val_loss: 0.2591 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 73/100
# 11/11 - 31s - loss: 0.1169 - accuracy: 0.9881 - val_loss: 0.2526 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 74/100
# 11/11 - 31s - loss: 0.1101 - accuracy: 0.9874 - val_loss: 0.2592 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 75/100
# 11/11 - 31s - loss: 0.1148 - accuracy: 0.9889 - val_loss: 0.2394 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 76/100
# 11/11 - 31s - loss: 0.1066 - accuracy: 0.9948 - val_loss: 0.2427 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 77/100
# 11/11 - 31s - loss: 0.1158 - accuracy: 0.9889 - val_loss: 0.2656 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 78/100
# 11/11 - 31s - loss: 0.1080 - accuracy: 0.9941 - val_loss: 0.2383 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 79/100
# 11/11 - 31s - loss: 0.1008 - accuracy: 0.9963 - val_loss: 0.2168 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 80/100
# 11/11 - 31s - loss: 0.1022 - accuracy: 0.9867 - val_loss: 0.2224 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 81/100
# 11/11 - 31s - loss: 0.0984 - accuracy: 0.9933 - val_loss: 0.2513 - val_accuracy: 0.9400 - 31s/epoch - 3s/step
# Epoch 82/100
# 11/11 - 31s - loss: 0.1012 - accuracy: 0.9941 - val_loss: 0.2418 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 83/100
# 11/11 - 31s - loss: 0.0989 - accuracy: 0.9889 - val_loss: 0.2504 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 84/100
# 11/11 - 31s - loss: 0.1005 - accuracy: 0.9933 - val_loss: 0.2109 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 85/100
# 11/11 - 31s - loss: 0.1016 - accuracy: 0.9896 - val_loss: 0.2331 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 86/100
# 11/11 - 31s - loss: 0.1133 - accuracy: 0.9867 - val_loss: 0.3299 - val_accuracy: 0.8800 - 31s/epoch - 3s/step
# Epoch 87/100
# 11/11 - 31s - loss: 0.1446 - accuracy: 0.9696 - val_loss: 0.2622 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 88/100
# 11/11 - 31s - loss: 0.1210 - accuracy: 0.9881 - val_loss: 0.2230 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 89/100
# 11/11 - 31s - loss: 0.0988 - accuracy: 0.9941 - val_loss: 0.2449 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 90/100
# 11/11 - 31s - loss: 0.1041 - accuracy: 0.9919 - val_loss: 0.2384 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 91/100
# 11/11 - 31s - loss: 0.0976 - accuracy: 0.9926 - val_loss: 0.2522 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 92/100
# 11/11 - 31s - loss: 0.0940 - accuracy: 0.9956 - val_loss: 0.2498 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 93/100
# 11/11 - 31s - loss: 0.1088 - accuracy: 0.9889 - val_loss: 0.2240 - val_accuracy: 0.9200 - 31s/epoch - 3s/step
# Epoch 94/100
# 11/11 - 31s - loss: 0.0966 - accuracy: 0.9919 - val_loss: 0.2378 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 95/100
# 11/11 - 31s - loss: 0.0982 - accuracy: 0.9926 - val_loss: 0.2168 - val_accuracy: 0.9467 - 31s/epoch - 3s/step
# Epoch 96/100
# 11/11 - 31s - loss: 0.0894 - accuracy: 0.9948 - val_loss: 0.2333 - val_accuracy: 0.9333 - 31s/epoch - 3s/step
# Epoch 97/100
# 11/11 - 31s - loss: 0.0908 - accuracy: 0.9963 - val_loss: 0.2152 - val_accuracy: 0.9267 - 31s/epoch - 3s/step
# Epoch 98/100
# 11/11 - 31s - loss: 0.0836 - accuracy: 0.9963 - val_loss: 0.2396 - val_accuracy: 0.9067 - 31s/epoch - 3s/step
# Epoch 99/100
# 11/11 - 31s - loss: 0.0836 - accuracy: 0.9963 - val_loss: 0.2384 - val_accuracy: 0.9133 - 31s/epoch - 3s/step
# Epoch 100/100
# 11/11 - 31s - loss: 0.0892 - accuracy: 0.9941 - val_loss: 0.2218 - val_accuracy: 0.9200 - 31s/epoch - 3s/step

# %%
ensemble_model.evaluate(validation_dataset , verbose = 1)
# Out:
# 2/2 [==============================] - 3s 464ms/step - loss: 0.2218 - accuracy: 0.9200
# [0.22176437079906464, 0.9200000166893005]

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Aedes  albopictus landing',
#  'Aedes aegypti landing',
#  'Aedes aegypti smashed',
#  'Aedes albopictus smashed',
#  'Culex quinquefasciatus landing',
#  'Culex quinquefasciatus smashed']

# %%
plt.figure(figsize=(20, 15))
for images, labels in validation_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = ensemble_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in validation_dataset:
    predictions = ensemble_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves with different colors and line styles
plt.figure(figsize=(10, 8))

colors = plt.cm.rainbow(np.linspace(0, 1, len(class_names)))

for i, color in zip(range(len(class_names)), colors):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr, tpr,
        label=f'{class_names[i]} (AUC = {roc_auc:.2f})',
        color=color,
        linestyle='-',  # You can customize line styles here
        linewidth=2,  # You can customize line width here
        alpha=0.8  # You can customize transparency here
    )

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification')
plt.legend(loc='lower right')
plt.grid(True)  # Add a grid for better readability
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# 4/4 [==============================] - 15s 408ms/step
# 1/1 [==============================] - 3s 3s/step
# ROC AUC for Aedes  albopictus landing: 0.9560
# ROC AUC for Aedes aegypti landing: 0.9320
# ROC AUC for Aedes aegypti smashed: 0.9230
# ROC AUC for Aedes albopictus smashed: 0.9734
# ROC AUC for Culex quinquefasciatus landing: 0.9573
# ROC AUC for Culex quinquefasciatus smashed: 0.9684
#                                 precision    recall  f1-score   support
#
#      Aedes  albopictus landing       0.96      0.92      0.94        25
#          Aedes aegypti landing       0.92      0.88      0.90        25
#          Aedes aegypti smashed       0.87      0.87      0.87        23
#       Aedes albopictus smashed       0.93      0.96      0.95        27
# Culex quinquefasciatus landing       0.93      0.93      0.93        29
# Culex quinquefasciatus smashed       0.91      0.95      0.93        21
#
#                       accuracy                           0.92       150
#                      macro avg       0.92      0.92      0.92       150
#                   weighted avg       0.92      0.92      0.92       150

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Set a custom color palette (cividis is a good choice for accessibility)
custom_palette = sns.color_palette("cividis", as_cmap=True)

# Plot the confusion matrix as a heatmap with custom styling
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=custom_palette, xticklabels=class_names, yticklabels=class_names, cbar=False)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.title('Confusion Matrix for m (Ensemble model 1)', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
from sklearn.metrics import cohen_kappa_score

kappa = cohen_kappa_score(true_labels, predicted_labels)
print(f'Cohen\'s Kappa: {kappa:.4f}')
# Out:
# Cohen's Kappa: 0.9038

# %%
from sklearn.metrics import matthews_corrcoef
import numpy as np

# Assuming true_labels and predicted_labels are your multiclass labels
mcc_values = [matthews_corrcoef(true_labels == i, predicted_labels == i) for i in np.unique(true_labels)]

average_mcc = np.mean(mcc_values)
print(f'Average Matthews Correlation Coefficient for Multiclass: {average_mcc:.4f}')
# Out:
# Average Matthews Correlation Coefficient for Multiclass: 0.9030

# %%
from sklearn.metrics import precision_recall_curve

plt.figure(figsize=(10, 8))

for i, color in zip(range(len(class_names)), colors):
    precision, recall, _ = precision_recall_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    plt.plot(
        recall, precision,
        label=f'{class_names[i]}',
        color=color,
        linestyle='-',
        linewidth=2,
        alpha=0.8
    )

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves for Multiclass Fish Diseases Classification (Ensemble Model 1)')
plt.legend(loc='lower left')
plt.grid(True)
plt.show()

# %%
# Assuming predictions is a matrix of predicted probabilities for each class
prediction_confidences = np.max(predictions, axis=1)

# Plot histogram of prediction confidences
plt.figure(figsize=(8, 6))
plt.hist(prediction_confidences, bins=20, edgecolor='black')
plt.xlabel('Prediction Confidence')
plt.ylabel('Frequency')
plt.title('Distribution of Prediction Confidences')
plt.show()
