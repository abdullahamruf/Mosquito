# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahamruf/Mosquito/blob/main/ADAM_ensemble_2(mendy_dataada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Average
model_1 = load_model('/content/drive/MyDrive/model-05-0.8400.hdf5')
model_1 = Model(inputs=model_1.inputs,
                outputs=model_1.outputs,
                name='name_of_model_1')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model_2 = load_model('/content/drive/MyDrive/model2-05-0.5667.hdf5')
model_2 = Model(inputs=model_2.inputs,
                outputs=model_2.outputs,
                name='name_of_model_2')

# %%
model_3 = load_model('/content/drive/MyDrive/resnetmosquito-04-0.8000.hdf5')
model_3 = Model(inputs=model_3.inputs,
                outputs=model_3.outputs,
                name='name_of_model_3')

# %%
models = [model_1, model_2 ,model_3]
model_input = Input(shape=(299, 299, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = Average()(model_outputs)
ensemble_model = Model(inputs=model_input, outputs=ensemble_output, name='ensemble')

# %%
import tensorflow as tf

# %%
base_learning_rate = 0.001
ensemble_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import os
from tensorflow import keras
import glob as gb
import pandas as pd
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D ,LeakyReLU

# %%
IMG_SIZE = (299, 299)  # resolution
directory = "/content/drive/MyDrive/Mosquito Images"
BATCH_SIZE = 128

# Training dataset
train_dataset = image_dataset_from_directory(directory,
                                             shuffle=True,
                                             labels='inferred',
                                             batch_size=BATCH_SIZE,
                                             image_size=IMG_SIZE,
                                             validation_split=0.1,
                                             subset='training',
                                             color_mode='rgb',
                                             seed=42)

# Validation dataset
validation_dataset = image_dataset_from_directory(directory,
                                                  shuffle=True,
                                                  labels='inferred',
                                                  batch_size=BATCH_SIZE,
                                                  image_size=IMG_SIZE,
                                                  validation_split=0.1,
                                                  subset='validation',
                                                  color_mode='rgb',
                                                  seed=42)
# Out:
# Found 1670 files belonging to 3 classes.
# Using 1503 files for training.
# Found 1670 files belonging to 3 classes.
# Using 167 files for validation.

# %%
sns.set_theme(style="whitegrid")
Data_imbalance = []
for folder in os.listdir(directory):
    files = gb.glob(pathname=str(directory + "/" + folder +"/*.*"))
    Data_imbalance.append(len(files))
# plt.figure(figsize=(13,7))
# sns.barplot(x=[ "Aedes aegypti landing", "EUS", "Aedes aegypti smashed","Aedes albopictus smashed","Culex quinquefasciatus landing","Culex quinquefasciatus smashed"], y=Data_imbalance, palette="rocket")
# plt.show()

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')

# %%
# total = 0
# for i in range(0,len(Data_imbalance)) :
#     total +=Data_imbalance[i]

# weight_for_0 = (1 / Data_imbalance[0]) * (total / 3.0)
# weight_for_1 = (1 / Data_imbalance[1]) * (total / 3.0)
# weight_for_2 = (1 / Data_imbalance[2]) * (total / 3.0)
# # weight_for_3 = (1 / Data_imbalance[3]) * (total / 6.0)
# # weight_for_4 = (1 / Data_imbalance[3]) * (total / 6.0)
# # weight_for_5 = (1 / Data_imbalance[3]) * (total / 6.0)

# class_weight = {0: weight_for_0, 1: weight_for_1, 2: weight_for_2}

# print('Weight for class 0: {:.2f}'.format(weight_for_0))
# print('Weight for class 1: {:.2f}'.format(weight_for_1))
# print('Weight for class 2: {:.2f}'.format(weight_for_2))
# # print('Weight for class 3: {:.2f}'.format(weight_for_3))
# # print('Weight for class 4: {:.2f}'.format(weight_for_4))
# # print('Weight for class 5: {:.2f}'.format(weight_for_5))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-22-a89a676414ae> in <cell line: 6>()
#       4
#       5 weight_for_0 = (1 / Data_imbalance[0]) * (total / 3.0)
# ----> 6 weight_for_1 = (1 / Data_imbalance[1]) * (total / 3.0)
#       7 weight_for_2 = (1 / Data_imbalance[2]) * (total / 3.0)
#       8 # weight_for_3 = (1 / Data_imbalance[3]) * (total / 6.0)
#
# ZeroDivisionError: division by zero

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
model_filepath="/content/drive/MyDrive/Colab Notebooks/emsemble-2-best-{epoch:02d}-{val_accuracy:.4f}.hdf5"
checkpoint = ModelCheckpoint(
    filepath = model_filepath ,
    monitor ='val_accuracy',
    mode = 'max' ,
    save_best_only =True ,
     verbose = 1

)

# %%
history = ensemble_model.fit(train_dataset , verbose=2 , epochs=100 ,
                               validation_data=validation_dataset , use_multiprocessing= True )
# Out:
# Epoch 1/100
# 12/12 - 120s - loss: 0.7860 - accuracy: 0.6667 - val_loss: 0.4341 - val_accuracy: 0.8323 - 120s/epoch - 10s/step
# Epoch 2/100
# 12/12 - 28s - loss: 0.3730 - accuracy: 0.8516 - val_loss: 0.2928 - val_accuracy: 0.8563 - 28s/epoch - 2s/step
# Epoch 3/100
# 12/12 - 28s - loss: 0.2602 - accuracy: 0.9175 - val_loss: 0.1940 - val_accuracy: 0.9581 - 28s/epoch - 2s/step
# Epoch 4/100
# 12/12 - 29s - loss: 0.2036 - accuracy: 0.9534 - val_loss: 0.1551 - val_accuracy: 0.9820 - 29s/epoch - 2s/step
# Epoch 5/100
# 12/12 - 28s - loss: 0.1651 - accuracy: 0.9747 - val_loss: 0.1114 - val_accuracy: 0.9940 - 28s/epoch - 2s/step
# Epoch 6/100
# 12/12 - 28s - loss: 0.1324 - accuracy: 0.9887 - val_loss: 0.0993 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 7/100
# 12/12 - 28s - loss: 0.1192 - accuracy: 0.9920 - val_loss: 0.0824 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 8/100
# 12/12 - 28s - loss: 0.1025 - accuracy: 0.9914 - val_loss: 0.0690 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 9/100
# 12/12 - 28s - loss: 0.0940 - accuracy: 0.9933 - val_loss: 0.0657 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 10/100
# 12/12 - 28s - loss: 0.0914 - accuracy: 0.9953 - val_loss: 0.0553 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 11/100
# 12/12 - 28s - loss: 0.0808 - accuracy: 0.9947 - val_loss: 0.0556 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 12/100
# 12/12 - 28s - loss: 0.0757 - accuracy: 0.9933 - val_loss: 0.0461 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 13/100
# 12/12 - 28s - loss: 0.0696 - accuracy: 0.9967 - val_loss: 0.0441 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 14/100
# 12/12 - 28s - loss: 0.0652 - accuracy: 0.9987 - val_loss: 0.0402 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 15/100
# 12/12 - 28s - loss: 0.0605 - accuracy: 0.9927 - val_loss: 0.0381 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 16/100
# 12/12 - 28s - loss: 0.0600 - accuracy: 0.9980 - val_loss: 0.0348 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 17/100
# 12/12 - 28s - loss: 0.0549 - accuracy: 0.9947 - val_loss: 0.0329 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 18/100
# 12/12 - 28s - loss: 0.0512 - accuracy: 0.9980 - val_loss: 0.0308 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 19/100
# 12/12 - 28s - loss: 0.0510 - accuracy: 0.9987 - val_loss: 0.0296 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 20/100
# 12/12 - 28s - loss: 0.0490 - accuracy: 0.9973 - val_loss: 0.0291 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 21/100
# 12/12 - 28s - loss: 0.0464 - accuracy: 0.9987 - val_loss: 0.0271 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 22/100
# 12/12 - 28s - loss: 0.0440 - accuracy: 0.9987 - val_loss: 0.0260 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 23/100
# 12/12 - 29s - loss: 0.0401 - accuracy: 0.9987 - val_loss: 0.0247 - val_accuracy: 1.0000 - 29s/epoch - 2s/step
# Epoch 24/100
# 12/12 - 28s - loss: 0.0418 - accuracy: 0.9993 - val_loss: 0.0236 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 25/100
# 12/12 - 28s - loss: 0.0420 - accuracy: 0.9980 - val_loss: 0.0226 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 26/100
# 12/12 - 28s - loss: 0.0414 - accuracy: 0.9980 - val_loss: 0.0217 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 27/100
# 12/12 - 28s - loss: 0.0395 - accuracy: 0.9987 - val_loss: 0.0209 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 28/100
# 12/12 - 28s - loss: 0.0393 - accuracy: 0.9987 - val_loss: 0.0202 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 29/100
# 12/12 - 28s - loss: 0.0364 - accuracy: 0.9993 - val_loss: 0.0195 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 30/100
# 12/12 - 28s - loss: 0.0338 - accuracy: 0.9987 - val_loss: 0.0187 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 31/100
# 12/12 - 28s - loss: 0.0355 - accuracy: 0.9987 - val_loss: 0.0184 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# 12/12 - 28s - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.0180 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 33/100
# 12/12 - 28s - loss: 0.0315 - accuracy: 0.9993 - val_loss: 0.0174 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 34/100
# 12/12 - 28s - loss: 0.0311 - accuracy: 0.9993 - val_loss: 0.0168 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 35/100
# 12/12 - 28s - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 36/100
# 12/12 - 28s - loss: 0.0293 - accuracy: 0.9993 - val_loss: 0.0161 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 37/100
# 12/12 - 28s - loss: 0.0278 - accuracy: 0.9993 - val_loss: 0.0158 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 38/100
# 12/12 - 28s - loss: 0.0278 - accuracy: 0.9993 - val_loss: 0.0152 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 39/100
# 12/12 - 28s - loss: 0.0295 - accuracy: 0.9993 - val_loss: 0.0149 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 40/100
# 12/12 - 28s - loss: 0.0281 - accuracy: 0.9993 - val_loss: 0.0144 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 41/100
# 12/12 - 28s - loss: 0.0270 - accuracy: 0.9987 - val_loss: 0.0142 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 42/100
# 12/12 - 28s - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.0137 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 43/100
# 12/12 - 28s - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 44/100
# 12/12 - 28s - loss: 0.0255 - accuracy: 0.9993 - val_loss: 0.0136 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 45/100
# 12/12 - 28s - loss: 0.0256 - accuracy: 0.9987 - val_loss: 0.0129 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 46/100
# 12/12 - 28s - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 47/100
# 12/12 - 28s - loss: 0.0259 - accuracy: 0.9993 - val_loss: 0.0123 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 48/100
# 12/12 - 28s - loss: 0.0230 - accuracy: 0.9987 - val_loss: 0.0123 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 49/100
# 12/12 - 28s - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 50/100
# 12/12 - 28s - loss: 0.0209 - accuracy: 0.9993 - val_loss: 0.0122 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 51/100
# 12/12 - 28s - loss: 0.0224 - accuracy: 0.9993 - val_loss: 0.0114 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 52/100
# 12/12 - 28s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 53/100
# 12/12 - 28s - loss: 0.0222 - accuracy: 0.9993 - val_loss: 0.0113 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 54/100
# 12/12 - 28s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 55/100
# 12/12 - 28s - loss: 0.0213 - accuracy: 0.9993 - val_loss: 0.0104 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 56/100
# 12/12 - 28s - loss: 0.0208 - accuracy: 0.9993 - val_loss: 0.0101 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 57/100
# 12/12 - 28s - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 58/100
# 12/12 - 28s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 59/100
# 12/12 - 28s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 60/100
# 12/12 - 28s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 61/100
# 12/12 - 28s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 62/100
# 12/12 - 28s - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 63/100
# 12/12 - 28s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 64/100
# 12/12 - 28s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 65/100
# 12/12 - 28s - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 66/100
# 12/12 - 28s - loss: 0.0175 - accuracy: 0.9993 - val_loss: 0.0094 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 67/100
# 12/12 - 28s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 68/100
# 12/12 - 28s - loss: 0.0189 - accuracy: 0.9993 - val_loss: 0.0090 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 69/100
# 12/12 - 28s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 70/100
# 12/12 - 28s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 71/100
# 12/12 - 28s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 72/100
# 12/12 - 28s - loss: 0.0172 - accuracy: 0.9993 - val_loss: 0.0084 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 73/100
# 12/12 - 28s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 74/100
# 12/12 - 28s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 75/100
# 12/12 - 28s - loss: 0.0186 - accuracy: 0.9993 - val_loss: 0.0081 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 76/100
# 12/12 - 28s - loss: 0.0171 - accuracy: 0.9993 - val_loss: 0.0081 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 77/100
# 12/12 - 28s - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 78/100
# 12/12 - 28s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 79/100
# 12/12 - 28s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 80/100
# 12/12 - 28s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 81/100
# 12/12 - 28s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 82/100
# 12/12 - 28s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 83/100
# 12/12 - 28s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 84/100
# 12/12 - 28s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 85/100
# 12/12 - 28s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 86/100
# 12/12 - 28s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 87/100
# 12/12 - 28s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 88/100
# 12/12 - 28s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 89/100
# 12/12 - 28s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 90/100
# 12/12 - 28s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 91/100
# 12/12 - 28s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 92/100
# 12/12 - 28s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 93/100
# 12/12 - 28s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 94/100
# 12/12 - 28s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 95/100
# 12/12 - 28s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 96/100
# 12/12 - 28s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 97/100
# 12/12 - 28s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 98/100
# 12/12 - 28s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 99/100
# 12/12 - 28s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000 - 28s/epoch - 2s/step
# Epoch 100/100
# 12/12 - 28s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000 - 28s/epoch - 2s/step

# %%
from tensorflow.keras.models import load_model

# %%
ensemble_model.evaluate(validation_dataset , verbose = 1)
# Out:
# 2/2 [==============================] - 3s 685ms/step - loss: 0.0062 - accuracy: 1.0000
# [0.006210807710886002, 1.0]

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['Aedes Aegypti', 'Anopheles Stephensi', 'Culex Quinquefasciatus']

# %%
plt.figure(figsize=(20, 15))
for images, labels in validation_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = ensemble_model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# Initialize empty lists to store true labels and predicted labels
true_labels = []
predicted_labels = []

# Iterate through the validation dataset and make predictions
for images, labels in validation_dataset:
    predictions = ensemble_model.predict(images)
    predicted_labels.extend(np.argmax(predictions, axis=1))
    true_labels.extend(labels.numpy())

# Binarize the true and predicted labels
true_labels_bin = label_binarize(true_labels, classes=np.unique(true_labels))
predicted_labels_bin = label_binarize(predicted_labels, classes=np.unique(predicted_labels))

# Compute class-specific ROC AUC values
roc_auc_per_class = []
for i in range(len(class_names)):
    roc_auc = roc_auc_score(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc_per_class.append(roc_auc)

# Generate the classification report
report = classification_report(true_labels, predicted_labels, target_names=class_names)

# Plot class-specific ROC curves with different colors and line styles
plt.figure(figsize=(10, 8))

colors = plt.cm.rainbow(np.linspace(0, 1, len(class_names)))

for i, color in zip(range(len(class_names)), colors):
    fpr, tpr, _ = roc_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    roc_auc = auc(fpr, tpr)

    plt.plot(
        fpr, tpr,
        label=f'{class_names[i]} (AUC = {roc_auc:.2f})',
        color=color,
        linestyle='-',  # You can customize line styles here
        linewidth=2,  # You can customize line width here
        alpha=0.8  # You can customize transparency here
    )

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multiclass Fish Diseases Classification')
plt.legend(loc='lower right')
plt.grid(True)  # Add a grid for better readability
plt.show()

# Print class-specific ROC AUC values
for i in range(len(class_names)):
    print(f'ROC AUC for {class_names[i]}: {roc_auc_per_class[i]:.4f}')

# Print the classification report
print(report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-28759746f367> in <cell line: 11>()
#       9
#      10 # Iterate through the validation dataset and make predictions
# ---> 11 for images, labels in validation_dataset:
#      12     predictions = ensemble_model.predict(images)
#      13     predicted_labels.extend(np.argmax(predictions, axis=1))
#
# NameError: name 'validation_dataset' is not defined

# %%
from sklearn.metrics import cohen_kappa_score

kappa = cohen_kappa_score(true_labels, predicted_labels)
print(f'Cohen\'s Kappa: {kappa:.4f}')

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Set a custom color palette (cividis is a good choice for accessibility)
custom_palette = sns.color_palette("cividis", as_cmap=True)

# Plot the confusion matrix as a heatmap with custom styling
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap=custom_palette, xticklabels=class_names, yticklabels=class_names, cbar=False)
plt.xlabel('Predicted Labels', fontsize=12)
plt.ylabel('True Labels', fontsize=12)
plt.title('Confusion Matrix (Ensemble model 2)', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
from sklearn.metrics import matthews_corrcoef
import numpy as np

# Assuming true_labels and predicted_labels are your multiclass labels
mcc_values = [matthews_corrcoef(true_labels == i, predicted_labels == i) for i in np.unique(true_labels)]

average_mcc = np.mean(mcc_values)
print(f'Average Matthews Correlation Coefficient for Multiclass: {average_mcc:.4f}')

# %%
from sklearn.metrics import precision_recall_curve

plt.figure(figsize=(10, 8))

for i, color in zip(range(len(class_names)), colors):
    precision, recall, _ = precision_recall_curve(true_labels_bin[:, i], predicted_labels_bin[:, i])
    plt.plot(
        recall, precision,
        label=f'{class_names[i]}',
        color=color,
        linestyle='-',
        linewidth=2,
        alpha=0.8
    )

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curves for Multiclass Mosquito Species  Classification (Ensemble Model 2)')
plt.legend(loc='lower left')
plt.grid(True)
plt.show()

# %%
from sklearn.calibration import calibration_curve

plt.figure(figsize=(8, 8))

for i in range(len(class_names)):
    prob_true, prob_pred = calibration_curve(true_labels_bin[:, i], predicted_labels_bin[:, i], n_bins=10, strategy='uniform')
    plt.plot(prob_pred, prob_true, marker='o', label=f'{class_names[i]}')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlabel('Mean Predicted Probability')
plt.ylabel('Fraction of Positives')
plt.title('Calibration Curve for Multiclass Classification')
plt.legend(loc='upper left')
plt.show()

# %%
# Assuming predictions is a matrix of predicted probabilities for each class
prediction_confidences = np.max(predictions, axis=1)

# Plot histogram of prediction confidences
plt.figure(figsize=(8, 6))
plt.hist(prediction_confidences, bins=20, edgecolor='black')
plt.xlabel('Prediction Confidence')
plt.ylabel('Frequency')
plt.title('Distribution of Prediction Confidences')
plt.show()
